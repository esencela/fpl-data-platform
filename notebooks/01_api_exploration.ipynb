# %%
import requests
import pandas as pd
import json
from pprint import pprint

# %%
base_url = 'https://fantasy.premierleague.com/api/'

# %%
def get_json_data(endpoint: str):
    response = requests.get(base_url+endpoint)
    print(response)
    return response.json()

# %%
data = get_json_data('bootstrap-static')
pprint(data, indent=2)
# Out:
# <Response [200]>
# { 'chips': [ { 'chip_type': 'transfer',
#                'id': 1,
#                'name': 'wildcard',
#                'number': 1,
#                'overrides': { 'element_types': [],
#                               'pick_multiplier': None,
#                               'rules': {},
#                               'scoring': {}},
#                'start_event': 2,
#                'stop_event': 19},
#              { 'chip_type': 'transfer',
#                'id': 2,
#                'name': 'wildcard',
#                'number': 1,
#                'overrides': { 'element_types': [],
#                               'pick_multiplier': None,
#                               'rules': {},
#                               'scoring': {}},
#                'start_event': 20,
#                'stop_event': 38},
#              { 'chip_type': 'transfer',
#                'id': 3,
#                'name': 'freehit',
#                'number': 1,
#                'overrides': { 'element_types': [],
#                               'pick_multiplier': None,
#                               'rules': {},
#                               'scoring': {}},
#                'start_event': 2,
#                'stop_event': 19},
#              { 'chip_type': 'team',
#                'id': 4,
#                'name': 'bboost',
#                'number': 1,
#                'overrides': { 'element_types': [],
#                               'pick_multiplier': None,
#                               'rules': {},
#                               'scoring': {}},
#                'start_event': 1,
#                'stop_event': 19},
#              { 'chip_type': 'team',
#                'id': 5,
#                'name': '3xc',
#                'number': 1,
#                'overrides': { 'element_types': [],
#                               'pick_multiplier': None,
#                               'rules': {},
#                               'scoring': {}},
#                'start_event': 1,
#                'stop_event': 19},
#              { 'chip_type': 'transfer',
#                'id': 6,
#                'name': 'freehit',
#                'number': 1,
#                'overrides': { 'element_types': [],
#                               'pick_multiplier': None,
#                               'rules': {},
#                               'scoring': {}},
#                'start_event': 20,
#                'stop_event': 38},
#              { 'chip_type': 'team',
#                'id': 7,
#                'name': 'bboost',
#                'number': 1,
#                'overrides': { 'element_types': [],
#                               'pick_multiplier': None,
#                               'rules': {},
#                               'scoring': {}},
#                'start_event': 20,
#                'stop_event': 38},
#              { 'chip_type': 'team',
#                'id': 8,
#                'name': '3xc',
#                'number': 1,
#                'overrides': { 'element_types': [],
#                               'pick_multiplier': None,
#                               'rules': {},
#                               'scoring': {}},
#                'start_event': 20,
#                'stop_event': 38}],
#   'element_stats': [ {'label': 'Minutes played', 'name': 'minutes'},
#                      {'label': 'Goals scored', 'name': 'goals_scored'},
#                      {'label': 'Assists', 'name': 'assists'},
#                      {'label': 'Clean sheets', 'name': 'clean_sheets'},
#                      {'label': 'Goals conceded', 'name': 'goals_conceded'},
#                      {'label': 'Own goals', 'name': 'own_goals'},
#                      {'label': 'Penalties saved', 'name': 'penalties_saved'},
#                      {'label': 'Penalties missed', 'name': 'penalties_missed'},
#                      {'label': 'Yellow cards', 'name': 'yellow_cards'},
#                      {'label': 'Red cards', 'name': 'red_cards'},
#                      {'label': 'Saves', 'name': 'saves'},
#                      {'label': 'Bonus', 'name': 'bonus'},
#                      {'label': 'Bonus Points System', 'name': 'bps'},
#                      {'label': 'Influence', 'name': 'influence'},
#                      {'label': 'Creativity', 'name': 'creativity'},
#                      {'label': 'Threat', 'name': 'threat'},
#                      {'label': 'ICT Index', 'name': 'ict_index'},
#                      { 'label': 'Clearances, blocks and interceptions',
#                        'name': 'clearances_blocks_interceptions'},
#                      {'label': 'Recoveries', 'name': 'recoveries'},
#                      {'label': 'Tackles', 'name': 'tackles'},
#                      { 'label': 'Defensive Contribution',
#                        'name': 'defensive_contribution'},
#                      {'label': 'Game(s) Started', 'name': 'starts'},
#                      {'label': 'Expected Goals', 'name': 'expected_goals'},
#                      {'label': 'Expected Assists', 'name': 'expected_assists'},
#                      { 'label': 'Expected Goal Involvements',
#                        'name': 'expected_goal_involvements'},
#                      { 'label': 'Expected Goals Conceded',
#                        'name': 'expected_goals_conceded'}],
#   'element_types': [ { 'element_count': 95,
#                        'id': 1,
#                        'plural_name': 'Goalkeepers',
#                        'plural_name_short': 'GKP',
#                        'singular_name': 'Goalkeeper',
#                        'singular_name_short': 'GKP',
#                        'squad_max_play': 1,
#                        'squad_max_select': None,
#                        'squad_min_play': 1,
#                        'squad_min_select': None,
#                        'squad_select': 2,
#                        'sub_positions_locked': [12],
#                        'ui_shirt_specific': True},
#                      { 'element_count': 268,
#                        'id': 2,
#                        'plural_name': 'Defenders',
#                        'plural_name_short': 'DEF',
#                        'singular_name': 'Defender',
#                        'singular_name_short': 'DEF',
#                        'squad_max_play': 5,
#                        'squad_max_select': None,
#                        'squad_min_play': 3,
#                        'squad_min_select': None,
#                        'squad_select': 5,
#                        'sub_positions_locked': [],
#                        'ui_shirt_specific': False},
#                      { 'element_count': 370,
#                        'id': 3,
#                        'plural_name': 'Midfielders',
#                        'plural_name_short': 'MID',
#                        'singular_name': 'Midfielder',
#                        'singular_name_short': 'MID',
#                        'squad_max_play': 5,
#                        'squad_max_select': None,
#                        'squad_min_play': 2,
#                        'squad_min_select': None,
#                        'squad_select': 5,
#                        'sub_positions_locked': [],
#                        'ui_shirt_specific': False},
#                      { 'element_count': 92,
#                        'id': 4,
#                        'plural_name': 'Forwards',
#                        'plural_name_short': 'FWD',
#                        'singular_name': 'Forward',
#                        'singular_name_short': 'FWD',
#                        'squad_max_play': 3,
#                        'squad_max_select': None,
#                        'squad_min_play': 1,
#                        'squad_min_select': None,
#                        'squad_select': 3,
#                        'sub_positions_locked': [],
#                        'ui_shirt_specific': False}],
#   'elements': [ { 'assists': 0,
#                   'birth_date': '1995-09-15',
#                   'bonus': 6,
#                   'bps': 515,
#                   'can_select': True,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': None,
#                   'chance_of_playing_this_round': None,
#                   'clean_sheets': 15,
#                   'clean_sheets_per_90': 0.48,
#                   'clearances_blocks_interceptions': 30,
#                   'code': 154561,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': 5,
#                   'cost_change_start_fall': -5,
#                   'creativity': '33.4',
#                   'creativity_rank': 376,
#                   'creativity_rank_type': 3,
#                   'defensive_contribution': 0,
#                   'defensive_contribution_per_90': 0.0,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 1,
#                   'element_type': 1,
#                   'ep_next': '6.7',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '0.06',
#                   'expected_assists_per_90': 0.0,
#                   'expected_goal_involvements': '0.06',
#                   'expected_goal_involvements_per_90': 0.0,
#                   'expected_goals': '0.00',
#                   'expected_goals_conceded': '22.30',
#                   'expected_goals_conceded_per_90': 0.72,
#                   'expected_goals_per_90': 0.0,
#                   'first_name': 'David',
#                   'form': '5.7',
#                   'form_rank': 23,
#                   'form_rank_type': 1,
#                   'goals_conceded': 22,
#                   'goals_conceded_per_90': 0.71,
#                   'goals_scored': 0,
#                   'has_temporary_code': False,
#                   'ict_index': '48.0',
#                   'ict_index_rank': 270,
#                   'ict_index_rank_type': 16,
#                   'id': 1,
#                   'in_dreamteam': True,
#                   'influence': '445.8',
#                   'influence_rank': 108,
#                   'influence_rank_type': 18,
#                   'known_name': '',
#                   'minutes': 2790,
#                   'news': '',
#                   'news_added': None,
#                   'now_cost': 60,
#                   'now_cost_rank': 86,
#                   'now_cost_rank_type': 1,
#                   'opta_code': 'p154561',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '154561.jpg',
#                   'points_per_game': '4.2',
#                   'points_per_game_rank': 51,
#                   'points_per_game_rank_type': 3,
#                   'price_change_percent': '0',
#                   'recoveries': 257,
#                   'red_cards': 0,
#                   'region': 200,
#                   'removed': False,
#                   'saves': 50,
#                   'saves_per_90': 1.61,
#                   'scout_news_link': '',
#                   'scout_risks': [],
#                   'second_name': 'Raya Martín',
#                   'selected_by_percent': '34.6',
#                   'selected_rank': 9,
#                   'selected_rank_type': 1,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 31,
#                   'starts_per_90': 1.0,
#                   'status': 'a',
#                   'tackles': 1,
#                   'team': 1,
#                   'team_code': 3,
#                   'team_join_date': '2024-07-04',
#                   'threat': '0.0',
#                   'threat_rank': 816,
#                   'threat_rank_type': 95,
#                   'total_points': 129,
#                   'transfers_in': 4165152,
#                   'transfers_in_event': 44475,
#                   'transfers_out': 2476167,
#                   'transfers_out_event': 8873,
#                   'value_form': '1.0',
#                   'value_season': '21.5',
#                   'web_name': 'Raya',
#                   'yellow_cards': 1},
#                 { 'assists': 0,
#                   'birth_date': '1994-10-03',
#                   'bonus': 0,
#                   'bps': 0,
#                   'can_select': True,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': None,
#                   'chance_of_playing_this_round': None,
#                   'clean_sheets': 0,
#                   'clean_sheets_per_90': 0,
#                   'clearances_blocks_interceptions': 0,
#                   'code': 109745,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': -5,
#                   'cost_change_start_fall': 5,
#                   'creativity': '0.0',
#                   'creativity_rank': 559,
#                   'creativity_rank_type': 51,
#                   'defensive_contribution': 0,
#                   'defensive_contribution_per_90': 0,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 0,
#                   'element_type': 1,
#                   'ep_next': '1.0',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '0.00',
#                   'expected_assists_per_90': 0,
#                   'expected_goal_involvements': '0.00',
#                   'expected_goal_involvements_per_90': 0,
#                   'expected_goals': '0.00',
#                   'expected_goals_conceded': '0.00',
#                   'expected_goals_conceded_per_90': 0,
#                   'expected_goals_per_90': 0,
#                   'first_name': 'Kepa',
#                   'form': '0.0',
#                   'form_rank': 448,
#                   'form_rank_type': 56,
#                   'goals_conceded': 0,
#                   'goals_conceded_per_90': 0,
#                   'goals_scored': 0,
#                   'has_temporary_code': False,
#                   'ict_index': '0.0',
#                   'ict_index_rank': 572,
#                   'ict_index_rank_type': 66,
#                   'id': 2,
#                   'in_dreamteam': False,
#                   'influence': '0.0',
#                   'influence_rank': 570,
#                   'influence_rank_type': 66,
#                   'known_name': '',
#                   'minutes': 0,
#                   'news': '',
#                   'news_added': None,
#                   'now_cost': 40,
#                   'now_cost_rank': 668,
#                   'now_cost_rank_type': 43,
#                   'opta_code': 'p109745',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '109745.jpg',
#                   'points_per_game': '0.0',
#                   'points_per_game_rank': 581,
#                   'points_per_game_rank_type': 66,
#                   'price_change_percent': '0',
#                   'recoveries': 0,
#                   'red_cards': 0,
#                   'region': 200,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0,
#                   'scout_news_link': '',
#                   'scout_risks': [],
#                   'second_name': 'Arrizabalaga Revuelta',
#                   'selected_by_percent': '0.4',
#                   'selected_rank': 285,
#                   'selected_rank_type': 37,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 0,
#                   'starts_per_90': 0,
#                   'status': 'a',
#                   'tackles': 0,
#                   'team': 1,
#                   'team_code': 3,
#                   'team_join_date': '2025-07-01',
#                   'threat': '0.0',
#                   'threat_rank': 529,
#                   'threat_rank_type': 38,
#                   'total_points': 0,
#                   'transfers_in': 14869,
#                   'transfers_in_event': 117,
#                   'transfers_out': 77564,
#                   'transfers_out_event': 155,
#                   'value_form': '0.0',
#                   'value_season': '0.0',
#                   'web_name': 'Arrizabalaga',
#                   'yellow_cards': 0},
#                 { 'assists': 0,
#                   'birth_date': '2002-04-13',
#                   'bonus': 0,
#                   'bps': 0,
#                   'can_select': False,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': 0,
#                   'chance_of_playing_this_round': 0,
#                   'clean_sheets': 0,
#                   'clean_sheets_per_90': 0,
#                   'clearances_blocks_interceptions': 0,
#                   'code': 463748,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': 0,
#                   'cost_change_start_fall': 0,
#                   'creativity': '0.0',
#                   'creativity_rank': 578,
#                   'creativity_rank_type': 62,
#                   'defensive_contribution': 0,
#                   'defensive_contribution_per_90': 0,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 0,
#                   'element_type': 1,
#                   'ep_next': '0.0',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '0.00',
#                   'expected_assists_per_90': 0,
#                   'expected_goal_involvements': '0.00',
#                   'expected_goal_involvements_per_90': 0,
#                   'expected_goals': '0.00',
#                   'expected_goals_conceded': '0.00',
#                   'expected_goals_conceded_per_90': 0,
#                   'expected_goals_per_90': 0,
#                   'first_name': 'Karl',
#                   'form': '0.0',
#                   'form_rank': 466,
#                   'form_rank_type': 66,
#                   'goals_conceded': 0,
#                   'goals_conceded_per_90': 0,
#                   'goals_scored': 0,
#                   'has_temporary_code': False,
#                   'ict_index': '0.0',
#                   'ict_index_rank': 589,
#                   'ict_index_rank_type': 75,
#                   'id': 3,
#                   'in_dreamteam': False,
#                   'influence': '0.0',
#                   'influence_rank': 587,
#                   'influence_rank_type': 75,
#                   'known_name': '',
#                   'minutes': 0,
#                   'news': 'Has joined Werder Bremen on loan for the rest of '
#                           'the season.',
#                   'news_added': '2025-08-26T13:44:02.357864Z',
#                   'now_cost': 40,
#                   'now_cost_rank': 689,
#                   'now_cost_rank_type': 54,
#                   'opta_code': 'p463748',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '463748.jpg',
#                   'points_per_game': '0.0',
#                   'points_per_game_rank': 598,
#                   'points_per_game_rank_type': 75,
#                   'price_change_percent': '0',
#                   'recoveries': 0,
#                   'red_cards': 0,
#                   'region': 67,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0,
#                   'scout_news_link': '',
#                   'scout_risks': [],
#                   'second_name': 'Hein',
#                   'selected_by_percent': '0.2',
#                   'selected_rank': 373,
#                   'selected_rank_type': 54,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 0,
#                   'starts_per_90': 0,
#                   'status': 'u',
#                   'tackles': 0,
#                   'team': 1,
#                   'team_code': 3,
#                   'team_join_date': '2020-10-28',
#                   'threat': '0.0',
#                   'threat_rank': 548,
#                   'threat_rank_type': 49,
#                   'total_points': 0,
#                   'transfers_in': 5545,
#                   'transfers_in_event': 0,
#                   'transfers_out': 48340,
#                   'transfers_out_event': 42,
#                   'value_form': '0.0',
#                   'value_season': '0.0',
#                   'web_name': 'Hein',
#                   'yellow_cards': 0},
#                 { 'assists': 0,
#                   'birth_date': '2006-03-13',
#                   'bonus': 0,
#                   'bps': 0,
#                   'can_select': True,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': None,
#                   'chance_of_playing_this_round': None,
#                   'clean_sheets': 0,
#                   'clean_sheets_per_90': 0,
#                   'clearances_blocks_interceptions': 0,
#                   'code': 551221,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': -1,
#                   'cost_change_start_fall': 1,
#                   'creativity': '0.0',
#                   'creativity_rank': 546,
#                   'creativity_rank_type': 43,
#                   'defensive_contribution': 0,
#                   'defensive_contribution_per_90': 0,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 0,
#                   'element_type': 1,
#                   'ep_next': '1.0',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '0.00',
#                   'expected_assists_per_90': 0,
#                   'expected_goal_involvements': '0.00',
#                   'expected_goal_involvements_per_90': 0,
#                   'expected_goals': '0.00',
#                   'expected_goals_conceded': '0.00',
#                   'expected_goals_conceded_per_90': 0,
#                   'expected_goals_per_90': 0,
#                   'first_name': 'Tommy',
#                   'form': '0.0',
#                   'form_rank': 435,
#                   'form_rank_type': 49,
#                   'goals_conceded': 0,
#                   'goals_conceded_per_90': 0,
#                   'goals_scored': 0,
#                   'has_temporary_code': False,
#                   'ict_index': '0.0',
#                   'ict_index_rank': 561,
#                   'ict_index_rank_type': 60,
#                   'id': 4,
#                   'in_dreamteam': False,
#                   'influence': '0.0',
#                   'influence_rank': 559,
#                   'influence_rank_type': 60,
#                   'known_name': '',
#                   'minutes': 0,
#                   'news': '',
#                   'news_added': None,
#                   'now_cost': 39,
#                   'now_cost_rank': 779,
#                   'now_cost_rank_type': 90,
#                   'opta_code': 'p551221',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '551221.jpg',
#                   'points_per_game': '0.0',
#                   'points_per_game_rank': 570,
#                   'points_per_game_rank_type': 60,
#                   'price_change_percent': '0',
#                   'recoveries': 0,
#                   'red_cards': 0,
#                   'region': 241,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0,
#                   'scout_news_link': '',
#                   'scout_risks': [],
#                   'second_name': 'Setford',
#                   'selected_by_percent': '0.2',
#                   'selected_rank': 362,
#                   'selected_rank_type': 52,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 0,
#                   'starts_per_90': 0,
#                   'status': 'a',
#                   'tackles': 0,
#                   'team': 1,
#                   'team_code': 3,
#                   'team_join_date': '2024-07-24',
#                   'threat': '0.0',
#                   'threat_rank': 515,
#                   'threat_rank_type': 30,
#                   'total_points': 0,
#                   'transfers_in': 33950,
#                   'transfers_in_event': 36,
#                   'transfers_out': 34237,
#                   'transfers_out_event': 135,
#                   'value_form': '0.0',
#                   'value_season': '0.0',
#                   'web_name': 'Setford',
#                   'yellow_cards': 0},
#                 { 'assists': 4,
#                   'birth_date': '1997-12-19',
#                   'bonus': 25,
#                   'bps': 593,
#                   'can_select': True,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': 75,
#                   'chance_of_playing_this_round': 100,
#                   'clean_sheets': 14,
#                   'clean_sheets_per_90': 0.58,
#                   'clearances_blocks_interceptions': 192,
#                   'code': 226597,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': 12,
#                   'cost_change_start_fall': -12,
#                   'creativity': '108.4',
#                   'creativity_rank': 262,
#                   'creativity_rank_type': 74,
#                   'defensive_contribution': 224,
#                   'defensive_contribution_per_90': 9.31,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 5,
#                   'element_type': 2,
#                   'ep_next': '8.0',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '1.65',
#                   'expected_assists_per_90': 0.07,
#                   'expected_goal_involvements': '3.55',
#                   'expected_goal_involvements_per_90': 0.15,
#                   'expected_goals': '1.90',
#                   'expected_goals_conceded': '15.82',
#                   'expected_goals_conceded_per_90': 0.66,
#                   'expected_goals_per_90': 0.08,
#                   'first_name': 'Gabriel',
#                   'form': '9.7',
#                   'form_rank': 2,
#                   'form_rank_type': 1,
#                   'goals_conceded': 15,
#                   'goals_conceded_per_90': 0.62,
#                   'goals_scored': 3,
#                   'has_temporary_code': False,
#                   'ict_index': '99.2',
#                   'ict_index_rank': 94,
#                   'ict_index_rank_type': 25,
#                   'id': 5,
#                   'in_dreamteam': True,
#                   'influence': '686.8',
#                   'influence_rank': 26,
#                   'influence_rank_type': 9,
#                   'known_name': 'Gabriel Magalhães',
#                   'minutes': 2165,
#                   'news': 'Knee injury - 75% chance of playing',
#                   'news_added': '2026-03-24T00:00:10.555559Z',
#                   'now_cost': 72,
#                   'now_cost_rank': 32,
#                   'now_cost_rank_type': 1,
#                   'opta_code': 'p226597',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '226597.jpg',
#                   'points_per_game': '6.9',
#                   'points_per_game_rank': 2,
#                   'points_per_game_rank_type': 1,
#                   'price_change_percent': '0',
#                   'recoveries': 46,
#                   'red_cards': 0,
#                   'region': 30,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0.0,
#                   'scout_news_link': 'https://www.arsenal.com/news/four-gunners-withdraw-international-duty?utm_source=premier_league&utm_medium=referral&utm_campaign=fantasy&utm_content=injuries-flag',
#                   'scout_risks': [],
#                   'second_name': 'dos Santos Magalhães',
#                   'selected_by_percent': '43.1',
#                   'selected_rank': 5,
#                   'selected_rank_type': 1,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 24,
#                   'starts_per_90': 1.0,
#                   'status': 'd',
#                   'tackles': 32,
#                   'team': 1,
#                   'team_code': 3,
#                   'team_join_date': '2020-09-01',
#                   'threat': '199.0',
#                   'threat_rank': 142,
#                   'threat_rank_type': 27,
#                   'total_points': 173,
#                   'transfers_in': 8325280,
#                   'transfers_in_event': 61940,
#                   'transfers_out': 5411821,
#                   'transfers_out_event': 25297,
#                   'value_form': '1.3',
#                   'value_season': '24.0',
#                   'web_name': 'Gabriel',
#                   'yellow_cards': 3},
#                 { 'assists': 0,
#                   'birth_date': '2001-03-24',
#                   'bonus': 9,
#                   'bps': 448,
#                   'can_select': True,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': 75,
#                   'chance_of_playing_this_round': 100,
#                   'clean_sheets': 11,
#                   'clean_sheets_per_90': 0.48,
#                   'clearances_blocks_interceptions': 121,
#                   'code': 462424,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': 1,
#                   'cost_change_start_fall': -1,
#                   'creativity': '156.4',
#                   'creativity_rank': 206,
#                   'creativity_rank_type': 53,
#                   'defensive_contribution': 150,
#                   'defensive_contribution_per_90': 6.51,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 2,
#                   'element_type': 2,
#                   'ep_next': '6.0',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '0.70',
#                   'expected_assists_per_90': 0.03,
#                   'expected_goal_involvements': '1.58',
#                   'expected_goal_involvements_per_90': 0.07,
#                   'expected_goals': '0.88',
#                   'expected_goals_conceded': '15.15',
#                   'expected_goals_conceded_per_90': 0.66,
#                   'expected_goals_per_90': 0.04,
#                   'first_name': 'William',
#                   'form': '7.0',
#                   'form_rank': 9,
#                   'form_rank_type': 6,
#                   'goals_conceded': 16,
#                   'goals_conceded_per_90': 0.69,
#                   'goals_scored': 1,
#                   'has_temporary_code': False,
#                   'ict_index': '66.4',
#                   'ict_index_rank': 202,
#                   'ict_index_rank_type': 69,
#                   'id': 6,
#                   'in_dreamteam': False,
#                   'influence': '433.6',
#                   'influence_rank': 116,
#                   'influence_rank_type': 52,
#                   'known_name': '',
#                   'minutes': 2074,
#                   'news': 'Ankle injury - 75% chance of playing',
#                   'news_added': '2026-03-23T13:00:10.244912Z',
#                   'now_cost': 61,
#                   'now_cost_rank': 85,
#                   'now_cost_rank_type': 4,
#                   'opta_code': 'p462424',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '462424.jpg',
#                   'points_per_game': '4.3',
#                   'points_per_game_rank': 45,
#                   'points_per_game_rank_type': 19,
#                   'price_change_percent': '0',
#                   'recoveries': 96,
#                   'red_cards': 0,
#                   'region': 73,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0.0,
#                   'scout_news_link': 'https://www.arsenal.com/news/four-gunners-withdraw-international-duty?utm_source=premier_league&utm_medium=referral&utm_campaign=fantasy&utm_content=injuries-flag',
#                   'scout_risks': [],
#                   'second_name': 'Saliba',
#                   'selected_by_percent': '13.2',
#                   'selected_rank': 27,
#                   'selected_rank_type': 9,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 24,
#                   'starts_per_90': 1.04,
#                   'status': 'd',
#                   'tackles': 29,
#                   'team': 1,
#                   'team_code': 3,
#                   'team_join_date': '2019-07-25',
#                   'threat': '74.0',
#                   'threat_rank': 295,
#                   'threat_rank_type': 87,
#                   'total_points': 107,
#                   'transfers_in': 1950068,
#                   'transfers_in_event': 19897,
#                   'transfers_out': 2302470,
#                   'transfers_out_event': 12523,
#                   'value_form': '1.1',
#                   'value_season': '17.5',
#                   'web_name': 'Saliba',
#                   'yellow_cards': 1},
#                 { 'assists': 2,
#                   'birth_date': '2002-05-19',
#                   'bonus': 4,
#                   'bps': 339,
#                   'can_select': True,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': 100,
#                   'chance_of_playing_this_round': 100,
#                   'clean_sheets': 11,
#                   'clean_sheets_per_90': 0.68,
#                   'clearances_blocks_interceptions': 64,
#                   'code': 466075,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': 1,
#                   'cost_change_start_fall': -1,
#                   'creativity': '127.9',
#                   'creativity_rank': 238,
#                   'creativity_rank_type': 63,
#                   'defensive_contribution': 95,
#                   'defensive_contribution_per_90': 5.91,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 2,
#                   'element_type': 2,
#                   'ep_next': '3.3',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '0.49',
#                   'expected_assists_per_90': 0.03,
#                   'expected_goal_involvements': '3.41',
#                   'expected_goal_involvements_per_90': 0.21,
#                   'expected_goals': '2.92',
#                   'expected_goals_conceded': '8.96',
#                   'expected_goals_conceded_per_90': 0.56,
#                   'expected_goals_per_90': 0.18,
#                   'first_name': 'Riccardo',
#                   'form': '2.3',
#                   'form_rank': 168,
#                   'form_rank_type': 67,
#                   'goals_conceded': 8,
#                   'goals_conceded_per_90': 0.5,
#                   'goals_scored': 1,
#                   'has_temporary_code': False,
#                   'ict_index': '62.2',
#                   'ict_index_rank': 219,
#                   'ict_index_rank_type': 75,
#                   'id': 7,
#                   'in_dreamteam': False,
#                   'influence': '244.4',
#                   'influence_rank': 245,
#                   'influence_rank_type': 97,
#                   'known_name': '',
#                   'minutes': 1446,
#                   'news': '',
#                   'news_added': '2026-03-07T22:30:07.329650Z',
#                   'now_cost': 56,
#                   'now_cost_rank': 131,
#                   'now_cost_rank_type': 13,
#                   'opta_code': 'p466075',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '466075.jpg',
#                   'points_per_game': '4.2',
#                   'points_per_game_rank': 50,
#                   'points_per_game_rank_type': 21,
#                   'price_change_percent': '0',
#                   'recoveries': 65,
#                   'red_cards': 0,
#                   'region': 106,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0.0,
#                   'scout_news_link': '',
#                   'scout_risks': [],
#                   'second_name': 'Calafiori',
#                   'selected_by_percent': '6.0',
#                   'selected_rank': 65,
#                   'selected_rank_type': 23,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 18,
#                   'starts_per_90': 1.12,
#                   'status': 'a',
#                   'tackles': 31,
#                   'team': 1,
#                   'team_code': 3,
#                   'team_join_date': '2024-07-29',
#                   'threat': '249.0',
#                   'threat_rank': 105,
#                   'threat_rank_type': 13,
#                   'total_points': 93,
#                   'transfers_in': 2642637,
#                   'transfers_in_event': 6194,
#                   'transfers_out': 2475157,
#                   'transfers_out_event': 1593,
#                   'value_form': '0.4',
#                   'value_season': '16.6',
#                   'web_name': 'Calafiori',
#                   'yellow_cards': 5},
#                 { 'assists': 6,
#                   'birth_date': '2001-06-17',
#                   'bonus': 9,
#                   'bps': 532,
#                   'can_select': True,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': 75,
#                   'chance_of_playing_this_round': 100,
#                   'clean_sheets': 13,
#                   'clean_sheets_per_90': 0.48,
#                   'clearances_blocks_interceptions': 82,
#                   'code': 445122,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': 8,
#                   'cost_change_start_fall': -8,
#                   'creativity': '402.6',
#                   'creativity_rank': 63,
#                   'creativity_rank_type': 12,
#                   'defensive_contribution': 148,
#                   'defensive_contribution_per_90': 5.43,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 3,
#                   'element_type': 2,
#                   'ep_next': '6.2',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '1.53',
#                   'expected_assists_per_90': 0.06,
#                   'expected_goal_involvements': '6.24',
#                   'expected_goal_involvements_per_90': 0.23,
#                   'expected_goals': '4.71',
#                   'expected_goals_conceded': '17.45',
#                   'expected_goals_conceded_per_90': 0.64,
#                   'expected_goals_per_90': 0.17,
#                   'first_name': 'Jurriën',
#                   'form': '7.3',
#                   'form_rank': 6,
#                   'form_rank_type': 4,
#                   'goals_conceded': 20,
#                   'goals_conceded_per_90': 0.73,
#                   'goals_scored': 3,
#                   'has_temporary_code': False,
#                   'ict_index': '125.7',
#                   'ict_index_rank': 50,
#                   'ict_index_rank_type': 5,
#                   'id': 8,
#                   'in_dreamteam': True,
#                   'influence': '499.0',
#                   'influence_rank': 80,
#                   'influence_rank_type': 37,
#                   'known_name': '',
#                   'minutes': 2452,
#                   'news': 'Ankle injury - 75% chance of playing',
#                   'news_added': '2026-03-23T13:00:10.259821Z',
#                   'now_cost': 63,
#                   'now_cost_rank': 70,
#                   'now_cost_rank_type': 3,
#                   'opta_code': 'p445122',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '445122.jpg',
#                   'points_per_game': '5.0',
#                   'points_per_game_rank': 13,
#                   'points_per_game_rank_type': 3,
#                   'price_change_percent': '0',
#                   'recoveries': 97,
#                   'red_cards': 0,
#                   'region': 152,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0.0,
#                   'scout_news_link': 'https://www.arsenal.com/news/four-gunners-withdraw-international-duty?utm_source=premier_league&utm_medium=referral&utm_campaign=fantasy&utm_content=injuries-flag',
#                   'scout_risks': [],
#                   'second_name': 'Timber',
#                   'selected_by_percent': '26.8',
#                   'selected_rank': 12,
#                   'selected_rank_type': 4,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 28,
#                   'starts_per_90': 1.03,
#                   'status': 'd',
#                   'tackles': 66,
#                   'team': 1,
#                   'team_code': 3,
#                   'team_join_date': '2023-07-14',
#                   'threat': '352.0',
#                   'threat_rank': 68,
#                   'threat_rank_type': 5,
#                   'total_points': 149,
#                   'transfers_in': 6762337,
#                   'transfers_in_event': 46215,
#                   'transfers_out': 4121667,
#                   'transfers_out_event': 44540,
#                   'value_form': '1.2',
#                   'value_season': '23.7',
#                   'web_name': 'J.Timber',
#                   'yellow_cards': 5},
#                 { 'assists': 0,
#                   'birth_date': '2000-02-15',
#                   'bonus': 0,
#                   'bps': 0,
#                   'can_select': False,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': 0,
#                   'chance_of_playing_this_round': 0,
#                   'clean_sheets': 0,
#                   'clean_sheets_per_90': 0,
#                   'clearances_blocks_interceptions': 0,
#                   'code': 440854,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': -1,
#                   'cost_change_start_fall': 1,
#                   'creativity': '0.0',
#                   'creativity_rank': 806,
#                   'creativity_rank_type': 268,
#                   'defensive_contribution': 0,
#                   'defensive_contribution_per_90': 0,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 0,
#                   'element_type': 2,
#                   'ep_next': '0.0',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '0.00',
#                   'expected_assists_per_90': 0,
#                   'expected_goal_involvements': '0.00',
#                   'expected_goal_involvements_per_90': 0,
#                   'expected_goals': '0.00',
#                   'expected_goals_conceded': '0.00',
#                   'expected_goals_conceded_per_90': 0,
#                   'expected_goals_per_90': 0,
#                   'first_name': 'Jakub',
#                   'form': '0.0',
#                   'form_rank': 786,
#                   'form_rank_type': 265,
#                   'goals_conceded': 0,
#                   'goals_conceded_per_90': 0,
#                   'goals_scored': 0,
#                   'has_temporary_code': False,
#                   'ict_index': '0.0',
#                   'ict_index_rank': 807,
#                   'ict_index_rank_type': 268,
#                   'id': 9,
#                   'in_dreamteam': False,
#                   'influence': '0.0',
#                   'influence_rank': 807,
#                   'influence_rank_type': 268,
#                   'known_name': '',
#                   'minutes': 0,
#                   'news': 'has joined Porto on loan for the rest of the '
#                           'season.',
#                   'news_added': '2025-09-02T13:37:25.929594Z',
#                   'now_cost': 54,
#                   'now_cost_rank': 170,
#                   'now_cost_rank_type': 20,
#                   'opta_code': 'p440854',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '440854.jpg',
#                   'points_per_game': '0.0',
#                   'points_per_game_rank': 808,
#                   'points_per_game_rank_type': 268,
#                   'price_change_percent': '0',
#                   'recoveries': 0,
#                   'red_cards': 0,
#                   'region': 172,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0,
#                   'scout_news_link': '',
#                   'scout_risks': [],
#                   'second_name': 'Kiwior',
#                   'selected_by_percent': '0.0',
#                   'selected_rank': 592,
#                   'selected_rank_type': 212,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 0,
#                   'starts_per_90': 0,
#                   'status': 'u',
#                   'tackles': 0,
#                   'team': 1,
#                   'team_code': 3,
#                   'team_join_date': '2023-01-23',
#                   'threat': '0.0',
#                   'threat_rank': 804,
#                   'threat_rank_type': 268,
#                   'total_points': 0,
#                   'transfers_in': 1119,
#                   'transfers_in_event': 0,
#                   'transfers_out': 10919,
#                   'transfers_out_event': 2,
#                   'value_form': '0.0',
#                   'value_season': '0.0',
#                   'web_name': 'Kiwior',
#                   'yellow_cards': 0},
#                 { 'assists': 0,
#                   'birth_date': '2006-09-26',
#                   'bonus': 0,
#                   'bps': 36,
# ...
#                   'known_name': '',
#                   'minutes': 89,
#                   'news': 'has joined Eintracht Frankfurt on loan for the rest '
#                           'of the season.',
#                   'news_added': '2026-01-08T10:36:01.900811Z',
#                   'now_cost': 60,
#                   'now_cost_rank': 89,
#                   'now_cost_rank_type': 27,
#                   'opta_code': 'p465680',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '465680.jpg',
#                   'points_per_game': '1.0',
#                   'points_per_game_rank': 507,
#                   'points_per_game_rank_type': 61,
#                   'price_change_percent': '0',
#                   'recoveries': 4,
#                   'red_cards': 0,
#                   'region': 73,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0.0,
#                   'scout_news_link': '',
#                   'scout_risks': [],
#                   'second_name': 'Kalimuendo',
#                   'selected_by_percent': '0.1',
#                   'selected_rank': 448,
#                   'selected_rank_type': 65,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 0,
#                   'starts_per_90': 0.0,
#                   'status': 'u',
#                   'tackles': 1,
#                   'team': 16,
#                   'team_code': 17,
#                   'team_join_date': '2025-08-18',
#                   'threat': '39.0',
#                   'threat_rank': 345,
#                   'threat_rank_type': 53,
#                   'total_points': 9,
#                   'transfers_in': 15291,
#                   'transfers_in_event': 0,
#                   'transfers_out': 18419,
#                   'transfers_out_event': 41,
#                   'value_form': '0.0',
#                   'value_season': '1.5',
#                   'web_name': 'Kalimuendo',
#                   'yellow_cards': 0},
#                 { 'assists': 0,
#                   'birth_date': '1996-02-13',
#                   'bonus': 0,
#                   'bps': 32,
#                   'can_select': True,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': 0,
#                   'chance_of_playing_this_round': 0,
#                   'clean_sheets': 1,
#                   'clean_sheets_per_90': 0.21,
#                   'clearances_blocks_interceptions': 4,
#                   'code': 221389,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': 0,
#                   'cost_change_start_fall': 0,
#                   'creativity': '0.0',
#                   'creativity_rank': 565,
#                   'creativity_rank_type': 54,
#                   'defensive_contribution': 0,
#                   'defensive_contribution_per_90': 0.0,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 0,
#                   'element_type': 1,
#                   'ep_next': '0.0',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '0.00',
#                   'expected_assists_per_90': 0.0,
#                   'expected_goal_involvements': '0.00',
#                   'expected_goal_involvements_per_90': 0.0,
#                   'expected_goals': '0.00',
#                   'expected_goals_conceded': '6.13',
#                   'expected_goals_conceded_per_90': 1.26,
#                   'expected_goals_per_90': 0.0,
#                   'first_name': 'John Victor',
#                   'form': '0.0',
#                   'form_rank': 453,
#                   'form_rank_type': 58,
#                   'goals_conceded': 8,
#                   'goals_conceded_per_90': 1.65,
#                   'goals_scored': 0,
#                   'has_temporary_code': False,
#                   'ict_index': '5.7',
#                   'ict_index_rank': 444,
#                   'ict_index_rank_type': 32,
#                   'id': 715,
#                   'in_dreamteam': False,
#                   'influence': '56.4',
#                   'influence_rank': 409,
#                   'influence_rank_type': 32,
#                   'known_name': 'John Victor',
#                   'minutes': 437,
#                   'news': 'Knee injury - Expected back 01 Jun',
#                   'news_added': '2026-01-04T21:30:13.580158Z',
#                   'now_cost': 40,
#                   'now_cost_rank': 675,
#                   'now_cost_rank_type': 46,
#                   'opta_code': 'p221389',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '221389.jpg',
#                   'points_per_game': '2.2',
#                   'points_per_game_rank': 306,
#                   'points_per_game_rank_type': 29,
#                   'price_change_percent': '0',
#                   'recoveries': 26,
#                   'red_cards': 0,
#                   'region': 30,
#                   'removed': False,
#                   'saves': 6,
#                   'saves_per_90': 1.24,
#                   'scout_news_link': '',
#                   'scout_risks': [],
#                   'second_name': 'Maciel Furtado',
#                   'selected_by_percent': '0.3',
#                   'selected_rank': 308,
#                   'selected_rank_type': 41,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 5,
#                   'starts_per_90': 1.03,
#                   'status': 'i',
#                   'tackles': 0,
#                   'team': 16,
#                   'team_code': 17,
#                   'team_join_date': '2025-08-31',
#                   'threat': '0.0',
#                   'threat_rank': 535,
#                   'threat_rank_type': 41,
#                   'total_points': 11,
#                   'transfers_in': 66265,
#                   'transfers_in_event': 25,
#                   'transfers_out': 48443,
#                   'transfers_out_event': 262,
#                   'value_form': '0.0',
#                   'value_season': '2.8',
#                   'web_name': 'John',
#                   'yellow_cards': 1},
#                 { 'assists': 0,
#                   'birth_date': '2003-03-19',
#                   'bonus': 0,
#                   'bps': 131,
#                   'can_select': True,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': 0,
#                   'chance_of_playing_this_round': 0,
#                   'clean_sheets': 3,
#                   'clean_sheets_per_90': 0.26,
#                   'clearances_blocks_interceptions': 37,
#                   'code': 500151,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': 0,
#                   'cost_change_start_fall': 0,
#                   'creativity': '123.2',
#                   'creativity_rank': 241,
#                   'creativity_rank_type': 65,
#                   'defensive_contribution': 57,
#                   'defensive_contribution_per_90': 5.0,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 1,
#                   'element_type': 2,
#                   'ep_next': '0.0',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '0.45',
#                   'expected_assists_per_90': 0.04,
#                   'expected_goal_involvements': '1.79',
#                   'expected_goal_involvements_per_90': 0.16,
#                   'expected_goals': '1.34',
#                   'expected_goals_conceded': '15.04',
#                   'expected_goals_conceded_per_90': 1.32,
#                   'expected_goals_per_90': 0.12,
#                   'first_name': 'Nicolò',
#                   'form': '0.0',
#                   'form_rank': 631,
#                   'form_rank_type': 246,
#                   'goals_conceded': 18,
#                   'goals_conceded_per_90': 1.58,
#                   'goals_scored': 2,
#                   'has_temporary_code': False,
#                   'ict_index': '43.5',
#                   'ict_index_rank': 285,
#                   'ict_index_rank_type': 94,
#                   'id': 716,
#                   'in_dreamteam': False,
#                   'influence': '216.6',
#                   'influence_rank': 264,
#                   'influence_rank_type': 106,
#                   'known_name': '',
#                   'minutes': 1025,
#                   'news': 'Knee injury - Unknown return date',
#                   'news_added': '2026-01-29T23:00:10.460624Z',
#                   'now_cost': 45,
#                   'now_cost_rank': 451,
#                   'now_cost_rank_type': 92,
#                   'opta_code': 'p500151',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '500151.jpg',
#                   'points_per_game': '2.8',
#                   'points_per_game_rank': 221,
#                   'points_per_game_rank_type': 88,
#                   'price_change_percent': '0',
#                   'recoveries': 27,
#                   'red_cards': 0,
#                   'region': 106,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0.0,
#                   'scout_news_link': 'https://www.nottinghamforest.co.uk/videos/7bd0fd3a-4ec6-45d0-a057-3122290cb79e?utm_source=premier_league&utm_medium=referral&utm_campaign=fantasy&utm_content=injuries-flag',
#                   'scout_risks': [],
#                   'second_name': 'Savona',
#                   'selected_by_percent': '0.1',
#                   'selected_rank': 578,
#                   'selected_rank_type': 207,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 11,
#                   'starts_per_90': 0.97,
#                   'status': 'i',
#                   'tackles': 20,
#                   'team': 16,
#                   'team_code': 17,
#                   'team_join_date': '2025-08-30',
#                   'threat': '94.0',
#                   'threat_rank': 267,
#                   'threat_rank_type': 77,
#                   'total_points': 39,
#                   'transfers_in': 46694,
#                   'transfers_in_event': 8,
#                   'transfers_out': 44364,
#                   'transfers_out_event': 61,
#                   'value_form': '0.0',
#                   'value_season': '8.7',
#                   'web_name': 'Savona',
#                   'yellow_cards': 2},
#                 { 'assists': 0,
#                   'birth_date': '2003-02-16',
#                   'bonus': 0,
#                   'bps': 0,
#                   'can_select': False,
#                   'can_transact': True,
#                   'chance_of_playing_next_round': 0,
#                   'chance_of_playing_this_round': 0,
#                   'clean_sheets': 0,
#                   'clean_sheets_per_90': 0,
#                   'clearances_blocks_interceptions': 0,
#                   'code': 560441,
#                   'corners_and_indirect_freekicks_order': None,
#                   'corners_and_indirect_freekicks_text': '',
#                   'cost_change_event': 0,
#                   'cost_change_event_fall': 0,
#                   'cost_change_start': 0,
#                   'cost_change_start_fall': 0,
#                   'creativity': '0.0',
#                   'creativity_rank': 721,
#                   'creativity_rank_type': 261,
#                   'defensive_contribution': 0,
#                   'defensive_contribution_per_90': 0,
#                   'direct_freekicks_order': None,
#                   'direct_freekicks_text': '',
#                   'dreamteam_count': 0,
#                   'element_type': 2,
#                   'ep_next': '0.0',
#                   'ep_this': '0.0',
#                   'event_points': 0,
#                   'expected_assists': '0.00',
#                   'expected_assists_per_90': 0,
#                   'expected_goal_involvements': '0.00',
#                   'expected_goal_involvements_per_90': 0,
#                   'expected_goals': '0.00',
#                   'expected_goals_conceded': '0.00',
#                   'expected_goals_conceded_per_90': 0,
#                   'expected_goals_per_90': 0,
#                   'first_name': 'Luis Eduardo',
#                   'form': '0.0',
#                   'form_rank': 648,
#                   'form_rank_type': 247,
#                   'goals_conceded': 0,
#                   'goals_conceded_per_90': 0,
#                   'goals_scored': 0,
#                   'has_temporary_code': False,
#                   'ict_index': '0.0',
#                   'ict_index_rank': 727,
#                   'ict_index_rank_type': 261,
#                   'id': 729,
#                   'in_dreamteam': False,
#                   'influence': '0.0',
#                   'influence_rank': 726,
#                   'influence_rank_type': 261,
#                   'known_name': '',
#                   'minutes': 0,
#                   'news': 'has joined Vasco de Gama on loan for the rest of '
#                           'the season.',
#                   'news_added': '2026-02-08T15:58:23.390743Z',
#                   'now_cost': 45,
#                   'now_cost_rank': 471,
#                   'now_cost_rank_type': 94,
#                   'opta_code': 'p560441',
#                   'own_goals': 0,
#                   'penalties_missed': 0,
#                   'penalties_order': None,
#                   'penalties_saved': 0,
#                   'penalties_text': '',
#                   'photo': '560441.jpg',
#                   'points_per_game': '0.0',
#                   'points_per_game_rank': 729,
#                   'points_per_game_rank_type': 261,
#                   'price_change_percent': '0',
#                   'recoveries': 0,
#                   'red_cards': 0,
#                   'region': 30,
#                   'removed': False,
#                   'saves': 0,
#                   'saves_per_90': 0,
#                   'scout_news_link': '',
#                   'scout_risks': [],
#                   'second_name': 'Soares da Silva',
#                   'selected_by_percent': '0.0',
#                   'selected_rank': 814,
#                   'selected_rank_type': 266,
#                   'special': False,
#                   'squad_number': None,
#                   'starts': 0,
#                   'starts_per_90': 0,
#                   'status': 'u',
#                   'tackles': 0,
#                   'team': 16,
#                   'team_code': 17,
#                   'team_join_date': '2025-09-01',
#                   'threat': '0.0',
#                   'threat_rank': 707,
#                   'threat_rank_type': 261,
#                   'total_points': 0,
#                   'transfers_in': 94,
#                   'transfers_in_event': 0,
#                   'transfers_out': 118,
#                   'transfers_out_event': 1,
#                   'value_form': '0.0',
#                   'value_season': '0.0',
#                   'web_name': 'Cuiabano',
#                   'yellow_cards': 0},
#                 {
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
list(data.keys())
# Out:
# ['chips',
#  'events',
#  'game_settings',
#  'game_config',
#  'phases',
#  'teams',
#  'total_players',
#  'element_stats',
#  'element_types',
#  'elements']

# %%
players = data['elements']

# %%
df_players = pd.json_normalize(players)

# %%
ordered_columns = df_players.columns.tolist()
ordered_columns.sort()
ordered_columns
# Out:
# ['assists',
#  'birth_date',
#  'bonus',
#  'bps',
#  'can_select',
#  'can_transact',
#  'chance_of_playing_next_round',
#  'chance_of_playing_this_round',
#  'clean_sheets',
#  'clean_sheets_per_90',
#  'clearances_blocks_interceptions',
#  'code',
#  'corners_and_indirect_freekicks_order',
#  'corners_and_indirect_freekicks_text',
#  'cost_change_event',
#  'cost_change_event_fall',
#  'cost_change_start',
#  'cost_change_start_fall',
#  'creativity',
#  'creativity_rank',
#  'creativity_rank_type',
#  'defensive_contribution',
#  'defensive_contribution_per_90',
#  'direct_freekicks_order',
#  'direct_freekicks_text',
#  'dreamteam_count',
#  'element_type',
#  'ep_next',
#  'ep_this',
#  'event_points',
#  'expected_assists',
#  'expected_assists_per_90',
#  'expected_goal_involvements',
#  'expected_goal_involvements_per_90',
#  'expected_goals',
#  'expected_goals_conceded',
#  'expected_goals_conceded_per_90',
#  'expected_goals_per_90',
#  'first_name',
#  'form',
#  'form_rank',
#  'form_rank_type',
#  'goals_conceded',
#  'goals_conceded_per_90',
#  'goals_scored',
#  'has_temporary_code',
#  'ict_index',
#  'ict_index_rank',
#  'ict_index_rank_type',
#  'id',
#  'in_dreamteam',
#  'influence',
#  'influence_rank',
#  'influence_rank_type',
#  'known_name',
#  'minutes',
#  'news',
#  'news_added',
#  'now_cost',
#  'now_cost_rank',
#  'now_cost_rank_type',
#  'opta_code',
#  'own_goals',
#  'penalties_missed',
#  'penalties_order',
#  'penalties_saved',
#  'penalties_text',
#  'photo',
#  'points_per_game',
#  'points_per_game_rank',
#  'points_per_game_rank_type',
#  'price_change_percent',
#  'recoveries',
#  'red_cards',
#  'region',
#  'removed',
#  'saves',
#  'saves_per_90',
#  'scout_news_link',
#  'scout_risks',
#  'second_name',
#  'selected_by_percent',
#  'selected_rank',
#  'selected_rank_type',
#  'special',
#  'squad_number',
#  'starts',
#  'starts_per_90',
#  'status',
#  'tackles',
#  'team',
#  'team_code',
#  'team_join_date',
#  'threat',
#  'threat_rank',
#  'threat_rank_type',
#  'total_points',
#  'transfers_in',
#  'transfers_in_event',
#  'transfers_out',
#  'transfers_out_event',
#  'value_form',
#  'value_season',
#  'web_name',
#  'yellow_cards']

# %%
columns = ['id', 'element_type', 'first_name', 'second_name', 'web_name', 'total_points', 'goals_scored', 'assists', 'expected_goals', 'expected_assists']
df_players[columns].sort_values('total_points', ascending=False).head(5)
# Out:
#       id  element_type  first_name           second_name     web_name  \
# 515  430             4      Erling               Haaland      Haaland
# 542  449             3       Bruno      Borges Fernandes  B.Fernandes
# 485   82             3     Antoine               Semenyo      Semenyo
# 4      5             2     Gabriel  dos Santos Magalhães      Gabriel
# 291  249             4  João Pedro    Junqueira de Jesus   João Pedro
#
#      total_points  goals_scored  assists expected_goals expected_assists
# 515           197            22        7          21.06             1.94
# 542           189             8       17          10.32             9.03
# 485           174            15        6           9.93             2.33
# 4             173             3        4           1.90             1.65
# 291           164            14        9          13.51             1.88

# %%
teams = data['teams']
df_teams = pd.json_normalize(teams)

# %%
df_teams.columns.tolist()
# Out:
# ['code',
#  'draw',
#  'form',
#  'id',
#  'loss',
#  'name',
#  'played',
#  'points',
#  'position',
#  'short_name',
#  'strength',
#  'team_division',
#  'unavailable',
#  'win',
#  'strength_overall_home',
#  'strength_overall_away',
#  'strength_attack_home',
#  'strength_attack_away',
#  'strength_defence_home',
#  'strength_defence_away',
#  'pulse_id']

# %%
df_teams.sort_values('position').head(5)
# Out:
#     code  draw  form  id  loss         name  played  points  position  \
# 0      3     0  None   1     0      Arsenal       0       0         1
# 12    43     0  None  13     0     Man City       0       0         2
# 13     1     0  None  14     0      Man Utd       0       0         3
# 1      7     0  None   2     0  Aston Villa       0       0         4
# 11    14     0  None  12     0    Liverpool       0       0         5
#
#    short_name  ...  team_division unavailable  win  strength_overall_home  \
# 0         ARS  ...           None       False    0                   1300
# 12        MCI  ...           None       False    0                   1255
# 13        MUN  ...           None       False    0                   1180
# 1         AVL  ...           None       False    0                   1155
# 11        LIV  ...           None       False    0                   1215
#
#     strength_overall_away  strength_attack_home  strength_attack_away  \
# 0                    1365                  1340                  1390
# 12                   1350                  1210                  1300
# 13                   1240                  1100                  1180
# 1                    1225                  1120                  1230
# 11                   1245                  1170                  1210
#
#     strength_defence_home  strength_defence_away  pulse_id
# 0                    1260                   1340         1
# 12                   1300                   1400        11
# 13                   1260                   1300        12
# 1                    1190                   1220         2
# 11                   1260                   1280        10
#
# [5 rows x 21 columns]

# %%
gameweeks = data['events']
df_gw = pd.json_normalize(gameweeks)

# %%
df_gw.columns.tolist()
# Out:
# ['id',
#  'name',
#  'deadline_time',
#  'release_time',
#  'average_entry_score',
#  'finished',
#  'data_checked',
#  'highest_scoring_entry',
#  'deadline_time_epoch',
#  'deadline_time_game_offset',
#  'highest_score',
#  'is_previous',
#  'is_current',
#  'is_next',
#  'cup_leagues_created',
#  'h2h_ko_matches_created',
#  'can_enter',
#  'can_manage',
#  'released',
#  'ranked_count',
#  'chip_plays',
#  'most_selected',
#  'most_transferred_in',
#  'top_element',
#  'transfers_made',
#  'most_captained',
#  'most_vice_captained',
#  'overrides.element_types',
#  'overrides.pick_multiplier',
#  'top_element_info.id',
#  'top_element_info.points',
#  'top_element_info']

# %%
df_gw.head()
# Out:
#    id        name         deadline_time release_time  average_entry_score  \
# 0   1  Gameweek 1  2025-08-15T17:30:00Z         None                   54
# 1   2  Gameweek 2  2025-08-22T17:30:00Z         None                   51
# 2   3  Gameweek 3  2025-08-30T10:00:00Z         None                   48
# 3   4  Gameweek 4  2025-09-13T10:00:00Z         None                   63
# 4   5  Gameweek 5  2025-09-20T10:00:00Z         None                   42
#
#    finished  data_checked  highest_scoring_entry  deadline_time_epoch  \
# 0      True          True              3772644.0           1755279000
# 1      True          True              2963810.0           1755883800
# 2      True          True              4374360.0           1756548000
# 3      True          True              7997042.0           1757757600
# 4      True          True              9985225.0           1758362400
#
#    deadline_time_game_offset  ...  most_transferred_in  top_element  \
# 0                          0  ...                  1.0        531.0
# 1                          0  ...                427.0          8.0
# 2                          0  ...                 82.0        260.0
# 3                          0  ...                419.0         26.0
# 4                          0  ...                 82.0        660.0
#
#    transfers_made  most_captained  most_vice_captained  \
# 0               0           381.0                235.0
# 1        18178809           381.0                235.0
# 2        27802596           430.0                381.0
# 3        27408255           381.0                249.0
# 4        16533109           381.0                249.0
#
#    overrides.element_types  overrides.pick_multiplier  top_element_info.id  \
# 0                       []                       None                531.0
# 1                       []                       None                  8.0
# 2                       []                       None                260.0
# 3                       []                       None                 26.0
# 4                       []                       None                660.0
#
#    top_element_info.points  top_element_info
# 0                     17.0               NaN
# 1                     24.0               NaN
# 2                     15.0               NaN
# 3                     16.0               NaN
# 4                     15.0               NaN
#
# [5 rows x 32 columns]

# %%
data = get_json_data('element-summary/430') # Haaland
pprint(data, indent=2)
# Out:
# <Response [200]>
# { 'fixtures': [ { 'code': 2562208,
#                   'difficulty': 4,
#                   'event': 32,
#                   'event_name': 'Gameweek 32',
#                   'finished': False,
#                   'id': 314,
#                   'is_home': False,
#                   'kickoff_time': '2026-04-12T15:30:00Z',
#                   'minutes': 0,
#                   'provisional_start_time': False,
#                   'team_a': 13,
#                   'team_a_score': None,
#                   'team_h': 7,
#                   'team_h_score': None},
#                 { 'code': 2562221,
#                   'difficulty': 4,
#                   'event': 33,
#                   'event_name': 'Gameweek 33',
#                   'finished': False,
#                   'id': 327,
#                   'is_home': True,
#                   'kickoff_time': '2026-04-19T15:30:00Z',
#                   'minutes': 0,
#                   'provisional_start_time': False,
#                   'team_a': 1,
#                   'team_a_score': None,
#                   'team_h': 13,
#                   'team_h_score': None},
#                 { 'code': 2562228,
#                   'difficulty': 2,
#                   'event': 34,
#                   'event_name': 'Gameweek 34',
#                   'finished': False,
#                   'id': 334,
#                   'is_home': False,
#                   'kickoff_time': '2026-04-26T13:00:00Z',
#                   'minutes': 0,
#                   'provisional_start_time': False,
#                   'team_a': 13,
#                   'team_a_score': None,
#                   'team_h': 3,
#                   'team_h_score': None},
#                 { 'code': 2562240,
#                   'difficulty': 3,
#                   'event': 35,
#                   'event_name': 'Gameweek 35',
#                   'finished': False,
#                   'id': 346,
#                   'is_home': False,
#                   'kickoff_time': '2026-05-04T19:00:00Z',
#                   'minutes': 0,
#                   'provisional_start_time': False,
#                   'team_a': 13,
#                   'team_a_score': None,
#                   'team_h': 9,
#                   'team_h_score': None},
#                 { 'code': 2562250,
#                   'difficulty': 3,
#                   'event': 36,
#                   'event_name': 'Gameweek 36',
#                   'finished': False,
#                   'id': 356,
#                   'is_home': True,
#                   'kickoff_time': '2026-05-09T14:00:00Z',
#                   'minutes': 0,
#                   'provisional_start_time': False,
#                   'team_a': 5,
#                   'team_a_score': None,
#                   'team_h': 13,
#                   'team_h_score': None},
#                 { 'code': 2562255,
#                   'difficulty': 3,
#                   'event': 37,
#                   'event_name': 'Gameweek 37',
#                   'finished': False,
#                   'id': 363,
#                   'is_home': False,
#                   'kickoff_time': '2026-05-17T14:00:00Z',
#                   'minutes': 0,
#                   'provisional_start_time': False,
#                   'team_a': 13,
#                   'team_a_score': None,
#                   'team_h': 4,
#                   'team_h_score': None},
#                 { 'code': 2562270,
#                   'difficulty': 3,
#                   'event': 38,
#                   'event_name': 'Gameweek 38',
#                   'finished': False,
#                   'id': 376,
#                   'is_home': True,
#                   'kickoff_time': '2026-05-24T15:00:00Z',
#                   'minutes': 0,
#                   'provisional_start_time': False,
#                   'team_a': 2,
#                   'team_a_score': None,
#                   'team_h': 13,
#                   'team_h_score': None},
#                 { 'code': 2562201,
#                   'difficulty': 3,
#                   'event': None,
#                   'finished': False,
#                   'id': 307,
#                   'is_home': True,
#                   'kickoff_time': None,
#                   'minutes': 0,
#                   'provisional_start_time': False,
#                   'team_a': 8,
#                   'team_a_score': None,
#                   'team_h': 13,
#                   'team_h_score': None}],
#   'history': [ { 'assists': 0,
#                  'bonus': 3,
#                  'bps': 49,
#                  'clean_sheets': 1,
#                  'clearances_blocks_interceptions': 0,
#                  'creativity': '0.3',
#                  'defensive_contribution': 2,
#                  'element': 430,
#                  'expected_assists': '0.00',
#                  'expected_goal_involvements': '1.99',
#                  'expected_goals': '1.99',
#                  'expected_goals_conceded': '0.35',
#                  'fixture': 7,
#                  'goals_conceded': 0,
#                  'goals_scored': 2,
#                  'ict_index': '12.9',
#                  'influence': '58.0',
#                  'kickoff_time': '2025-08-16T16:30:00Z',
#                  'minutes': 72,
#                  'modified': False,
#                  'opponent_team': 20,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 1,
#                  'red_cards': 0,
#                  'round': 1,
#                  'saves': 0,
#                  'selected': 2283987,
#                  'starts': 1,
#                  'tackles': 1,
#                  'team_a_score': 4,
#                  'team_h_score': 0,
#                  'threat': '71.0',
#                  'total_points': 13,
#                  'transfers_balance': 0,
#                  'transfers_in': 0,
#                  'transfers_out': 0,
#                  'value': 140,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 6,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 1,
#                  'creativity': '15.2',
#                  'defensive_contribution': 4,
#                  'element': 430,
#                  'expected_assists': '0.30',
#                  'expected_goal_involvements': '0.77',
#                  'expected_goals': '0.47',
#                  'expected_goals_conceded': '1.11',
#                  'fixture': 18,
#                  'goals_conceded': 2,
#                  'goals_scored': 0,
#                  'ict_index': '3.2',
#                  'influence': '1.4',
#                  'kickoff_time': '2025-08-23T11:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 18,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 3,
#                  'red_cards': 0,
#                  'round': 2,
#                  'saves': 0,
#                  'selected': 3276879,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 2,
#                  'team_h_score': 0,
#                  'threat': '15.0',
#                  'total_points': 2,
#                  'transfers_balance': 396573,
#                  'transfers_in': 446334,
#                  'transfers_out': 49761,
#                  'value': 140,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 3,
#                  'bps': 29,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 0,
#                  'creativity': '0.4',
#                  'defensive_contribution': 1,
#                  'element': 430,
#                  'expected_assists': '0.00',
#                  'expected_goal_involvements': '1.40',
#                  'expected_goals': '1.40',
#                  'expected_goals_conceded': '2.30',
#                  'fixture': 22,
#                  'goals_conceded': 2,
#                  'goals_scored': 1,
#                  'ict_index': '12.7',
#                  'influence': '30.4',
#                  'kickoff_time': '2025-08-31T13:00:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 6,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 1,
#                  'red_cards': 0,
#                  'round': 3,
#                  'saves': 0,
#                  'selected': 3747441,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 1,
#                  'team_h_score': 2,
#                  'threat': '96.0',
#                  'total_points': 9,
#                  'transfers_balance': 179096,
#                  'transfers_in': 366370,
#                  'transfers_out': 187274,
#                  'value': 141,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 3,
#                  'bps': 63,
#                  'clean_sheets': 1,
#                  'clearances_blocks_interceptions': 6,
#                  'creativity': '12.9',
#                  'defensive_contribution': 8,
#                  'element': 430,
#                  'expected_assists': '0.01',
#                  'expected_goal_involvements': '1.81',
#                  'expected_goals': '1.80',
#                  'expected_goals_conceded': '1.42',
#                  'fixture': 38,
#                  'goals_conceded': 0,
#                  'goals_scored': 2,
#                  'ict_index': '16.2',
#                  'influence': '78.8',
#                  'kickoff_time': '2025-09-14T15:30:00Z',
#                  'minutes': 86,
#                  'modified': False,
#                  'opponent_team': 14,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 2,
#                  'red_cards': 0,
#                  'round': 4,
#                  'saves': 0,
#                  'selected': 3931425,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 0,
#                  'team_h_score': 3,
#                  'threat': '70.0',
#                  'total_points': 13,
#                  'transfers_balance': 209666,
#                  'transfers_in': 435454,
#                  'transfers_out': 225788,
#                  'value': 141,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 3,
#                  'bps': 32,
#                  'clean_sheets': 1,
#                  'clearances_blocks_interceptions': 2,
#                  'creativity': '2.1',
#                  'defensive_contribution': 5,
#                  'element': 430,
#                  'expected_assists': '0.01',
#                  'expected_goal_involvements': '0.53',
#                  'expected_goals': '0.52',
#                  'expected_goals_conceded': '0.77',
#                  'fixture': 41,
#                  'goals_conceded': 0,
#                  'goals_scored': 1,
#                  'ict_index': '7.2',
#                  'influence': '35.4',
#                  'kickoff_time': '2025-09-21T15:30:00Z',
#                  'minutes': 75,
#                  'modified': False,
#                  'opponent_team': 1,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 3,
#                  'red_cards': 0,
#                  'round': 5,
#                  'saves': 0,
#                  'selected': 4419019,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 1,
#                  'team_h_score': 1,
#                  'threat': '34.0',
#                  'total_points': 9,
#                  'transfers_balance': 405468,
#                  'transfers_in': 479550,
#                  'transfers_out': 74082,
#                  'value': 142,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 1,
#                  'bonus': 3,
#                  'bps': 68,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 2,
#                  'creativity': '20.8',
#                  'defensive_contribution': 4,
#                  'element': 430,
#                  'expected_assists': '0.24',
#                  'expected_goal_involvements': '1.41',
#                  'expected_goals': '1.17',
#                  'expected_goals_conceded': '0.41',
#                  'fixture': 57,
#                  'goals_conceded': 1,
#                  'goals_scored': 2,
#                  'ict_index': '18.4',
#                  'influence': '85.4',
#                  'kickoff_time': '2025-09-27T14:00:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 3,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 2,
#                  'red_cards': 0,
#                  'round': 6,
#                  'saves': 0,
#                  'selected': 5991428,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 1,
#                  'team_h_score': 5,
#                  'threat': '78.0',
#                  'total_points': 16,
#                  'transfers_balance': 1415070,
#                  'transfers_in': 1490551,
#                  'transfers_out': 75481,
#                  'value': 143,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 2,
#                  'bps': 36,
#                  'clean_sheets': 1,
#                  'clearances_blocks_interceptions': 2,
#                  'creativity': '3.4',
#                  'defensive_contribution': 2,
#                  'element': 430,
#                  'expected_assists': '0.01',
#                  'expected_goal_involvements': '0.30',
#                  'expected_goals': '0.29',
#                  'expected_goals_conceded': '0.83',
#                  'fixture': 64,
#                  'goals_conceded': 0,
#                  'goals_scored': 1,
#                  'ict_index': '6.2',
#                  'influence': '35.4',
#                  'kickoff_time': '2025-10-05T15:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 5,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 7,
#                  'saves': 0,
#                  'selected': 7060510,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 1,
#                  'team_h_score': 0,
#                  'threat': '23.0',
#                  'total_points': 8,
#                  'transfers_balance': 1031965,
#                  'transfers_in': 1038671,
#                  'transfers_out': 6706,
#                  'value': 144,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 3,
#                  'bps': 62,
#                  'clean_sheets': 1,
#                  'clearances_blocks_interceptions': 2,
#                  'creativity': '1.9',
#                  'defensive_contribution': 4,
#                  'element': 430,
#                  'expected_assists': '0.02',
#                  'expected_goal_involvements': '1.00',
#                  'expected_goals': '0.98',
#                  'expected_goals_conceded': '0.81',
#                  'fixture': 76,
#                  'goals_conceded': 0,
#                  'goals_scored': 2,
#                  'ict_index': '16.4',
#                  'influence': '77.4',
#                  'kickoff_time': '2025-10-18T14:00:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 9,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 2,
#                  'red_cards': 0,
#                  'round': 8,
#                  'saves': 0,
#                  'selected': 7826831,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 0,
#                  'team_h_score': 2,
#                  'threat': '85.0',
#                  'total_points': 13,
#                  'transfers_balance': 707569,
#                  'transfers_in': 717731,
#                  'transfers_out': 10162,
#                  'value': 146,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 9,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 3,
#                  'creativity': '2.6',
#                  'defensive_contribution': 3,
#                  'element': 430,
#                  'expected_assists': '0.01',
#                  'expected_goal_involvements': '0.24',
#                  'expected_goals': '0.23',
#                  'expected_goals_conceded': '0.81',
#                  'fixture': 82,
#                  'goals_conceded': 1,
#                  'goals_scored': 0,
#                  'ict_index': '7.1',
#                  'influence': '15.2',
#                  'kickoff_time': '2025-10-26T14:00:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 2,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 9,
#                  'saves': 0,
#                  'selected': 8327859,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 0,
#                  'team_h_score': 1,
#                  'threat': '53.0',
#                  'total_points': 2,
#                  'transfers_balance': 470274,
#                  'transfers_in': 478726,
#                  'transfers_out': 8452,
#                  'value': 147,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 3,
#                  'bps': 62,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 1,
#                  'creativity': '3.8',
#                  'defensive_contribution': 1,
#                  'element': 430,
#                  'expected_assists': '0.01',
#                  'expected_goal_involvements': '1.34',
#                  'expected_goals': '1.33',
#                  'expected_goals_conceded': '0.71',
#                  'fixture': 96,
#                  'goals_conceded': 1,
#                  'goals_scored': 2,
#                  'ict_index': '15.7',
#                  'influence': '71.6',
#                  'kickoff_time': '2025-11-02T16:30:00Z',
#                  'minutes': 81,
#                  'modified': False,
#                  'opponent_team': 4,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 10,
#                  'saves': 0,
#                  'selected': 8565665,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 1,
#                  'team_h_score': 3,
#                  'threat': '82.0',
#                  'total_points': 13,
#                  'transfers_balance': 202821,
#                  'transfers_in': 228200,
#                  'transfers_out': 25379,
#                  'value': 148,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 28,
#                  'clean_sheets': 1,
#                  'clearances_blocks_interceptions': 1,
#                  'creativity': '1.6',
#                  'defensive_contribution': 2,
#                  'element': 430,
#                  'expected_assists': '0.09',
#                  'expected_goal_involvements': '0.94',
#                  'expected_goals': '0.85',
#                  'expected_goals_conceded': '0.71',
#                  'fixture': 106,
#                  'goals_conceded': 0,
#                  'goals_scored': 1,
#                  'ict_index': '8.1',
#                  'influence': '37.0',
#                  'kickoff_time': '2025-11-09T16:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 12,
#                  'own_goals': 0,
#                  'penalties_missed': 1,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 11,
#                  'saves': 0,
#                  'selected': 8719190,
#                  'starts': 1,
#                  'tackles': 1,
#                  'team_a_score': 0,
#                  'team_h_score': 3,
#                  'threat': '42.0',
#                  'total_points': 4,
#                  'transfers_balance': 120567,
#                  'transfers_in': 148317,
#                  'transfers_out': 27750,
#                  'value': 148,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 2,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 1,
#                  'creativity': '1.3',
#                  'defensive_contribution': 3,
#                  'element': 430,
#                  'expected_assists': '0.00',
#                  'expected_goal_involvements': '1.54',
#                  'expected_goals': '1.54',
#                  'expected_goals_conceded': '2.24',
#                  'fixture': 119,
#                  'goals_conceded': 2,
#                  'goals_scored': 0,
#                  'ict_index': '6.0',
#                  'influence': '6.4',
#                  'kickoff_time': '2025-11-22T17:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 15,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 1,
#                  'red_cards': 0,
#                  'round': 12,
#                  'saves': 0,
#                  'selected': 8883070,
#                  'starts': 1,
#                  'tackles': 1,
#                  'team_a_score': 1,
#                  'team_h_score': 2,
#                  'threat': '52.0',
#                  'total_points': 2,
#                  'transfers_balance': 115193,
#                  'transfers_in': 129451,
#                  'transfers_out': 14258,
#                  'value': 149,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 9,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 4,
#                  'creativity': '10.6',
#                  'defensive_contribution': 5,
#                  'element': 430,
#                  'expected_assists': '0.01',
#                  'expected_goal_involvements': '0.14',
#                  'expected_goals': '0.13',
#                  'expected_goals_conceded': '1.54',
#                  'fixture': 126,
#                  'goals_conceded': 2,
#                  'goals_scored': 0,
#                  'ict_index': '5.8',
#                  'influence': '16.6',
#                  'kickoff_time': '2025-11-29T15:00:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 11,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 13,
#                  'saves': 0,
#                  'selected': 9068878,
#                  'starts': 1,
#                  'tackles': 1,
#                  'team_a_score': 2,
#                  'team_h_score': 3,
#                  'threat': '31.0',
#                  'total_points': 2,
#                  'transfers_balance': 129287,
#                  'transfers_in': 136029,
#                  'transfers_out': 6742,
#                  'value': 149,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 2,
#                  'bonus': 2,
#                  'bps': 52,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 1,
#                  'creativity': '27.3',
#                  'defensive_contribution': 2,
#                  'element': 430,
#                  'expected_assists': '0.30',
#                  'expected_goal_involvements': '1.21',
#                  'expected_goals': '0.91',
#                  'expected_goals_conceded': '0.91',
#                  'fixture': 135,
#                  'goals_conceded': 4,
#                  'goals_scored': 1,
#                  'ict_index': '13.6',
#                  'influence': '64.4',
#                  'kickoff_time': '2025-12-02T19:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 10,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 1,
#                  'red_cards': 0,
#                  'round': 14,
#                  'saves': 0,
#                  'selected': 9052991,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 5,
#                  'team_h_score': 4,
#                  'threat': '44.0',
#                  'total_points': 14,
#                  'transfers_balance': -5968,
#                  'transfers_in': 38963,
#                  'transfers_out': 44931,
#                  'value': 149,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 5,
#                  'clean_sheets': 1,
#                  'clearances_blocks_interceptions': 2,
#                  'creativity': '0.8',
#                  'defensive_contribution': 3,
#                  'element': 430,
#                  'expected_assists': '0.01',
#                  'expected_goal_involvements': '0.44',
#                  'expected_goals': '0.43',
#                  'expected_goals_conceded': '0.66',
#                  'fixture': 147,
#                  'goals_conceded': 0,
#                  'goals_scored': 0,
#                  'ict_index': '1.5',
#                  'influence': '5.6',
#                  'kickoff_time': '2025-12-06T15:00:00Z',
#                  'minutes': 68,
#                  'modified': False,
#                  'opponent_team': 17,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 1,
#                  'red_cards': 0,
#                  'round': 15,
#                  'saves': 0,
#                  'selected': 9177769,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 0,
#                  'team_h_score': 3,
#                  'threat': '9.0',
#                  'total_points': 2,
#                  'transfers_balance': 88114,
#                  'transfers_in': 94687,
#                  'transfers_out': 6573,
#                  'value': 150,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 3,
#                  'bps': 53,
#                  'clean_sheets': 1,
#                  'clearances_blocks_interceptions': 3,
#                  'creativity': '0.5',
#                  'defensive_contribution': 8,
#                  'element': 430,
#                  'expected_assists': '0.00',
#                  'expected_goal_involvements': '0.96',
#                  'expected_goals': '0.96',
#                  'expected_goals_conceded': '1.88',
#                  'fixture': 155,
#                  'goals_conceded': 0,
#                  'goals_scored': 2,
#                  'ict_index': '11.2',
#                  'influence': '75.0',
#                  'kickoff_time': '2025-12-14T14:00:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 8,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 2,
#                  'red_cards': 0,
#                  'round': 16,
#                  'saves': 0,
#                  'selected': 9218490,
#                  'starts': 1,
#                  'tackles': 3,
#                  'team_a_score': 3,
#                  'team_h_score': 0,
#                  'threat': '36.0',
#                  'total_points': 13,
#                  'transfers_balance': 35479,
#                  'transfers_in': 98945,
#                  'transfers_out': 63466,
#                  'value': 150,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 1,
#                  'bonus': 3,
#                  'bps': 66,
#                  'clean_sheets': 1,
#                  'clearances_blocks_interceptions': 0,
#                  'creativity': '10.8',
#                  'defensive_contribution': 0,
#                  'element': 430,
#                  'expected_assists': '0.07',
#                  'expected_goal_involvements': '1.09',
#                  'expected_goals': '1.02',
#                  'expected_goals_conceded': '0.98',
#                  'fixture': 167,
#                  'goals_conceded': 0,
#                  'goals_scored': 2,
#                  'ict_index': '15.7',
#                  'influence': '78.2',
#                  'kickoff_time': '2025-12-20T15:00:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 19,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 17,
#                  'saves': 0,
#                  'selected': 9359701,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 0,
#                  'team_h_score': 3,
#                  'threat': '68.0',
#                  'total_points': 16,
#                  'transfers_balance': 85243,
#                  'transfers_in': 94186,
#                  'transfers_out': 8943,
#                  'value': 150,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 5,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 1,
#                  'creativity': '10.6',
#                  'defensive_contribution': 3,
#                  'element': 430,
#                  'expected_assists': '0.11',
#                  'expected_goal_involvements': '0.28',
#                  'expected_goals': '0.17',
#                  'expected_goals_conceded': '0.55',
#                  'fixture': 178,
#                  'goals_conceded': 1,
#                  'goals_scored': 0,
#                  'ict_index': '2.8',
#                  'influence': '2.4',
#                  'kickoff_time': '2025-12-27T12:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 16,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 2,
#                  'red_cards': 0,
#                  'round': 18,
#                  'saves': 0,
#                  'selected': 9439331,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 2,
#                  'team_h_score': 1,
#                  'threat': '15.0',
#                  'total_points': 2,
#                  'transfers_balance': 59888,
#                  'transfers_in': 70149,
#                  'transfers_out': 10261,
#                  'value': 151,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 3,
#                  'clean_sheets': 1,
#                  'clearances_blocks_interceptions': 0,
#                  'creativity': '11.3',
#                  'defensive_contribution': 4,
#                  'element': 430,
#                  'expected_assists': '0.02',
#                  'expected_goal_involvements': '0.36',
#                  'expected_goals': '0.34',
#                  'expected_goals_conceded': '0.81',
#                  'fixture': 189,
#                  'goals_conceded': 0,
#                  'goals_scored': 0,
#                  'ict_index': '4.8',
#                  'influence': '8.0',
#                  'kickoff_time': '2026-01-01T20:00:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 17,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 1,
#                  'red_cards': 0,
#                  'round': 19,
#                  'saves': 0,
#                  'selected': 9445379,
#                  'starts': 1,
#                  'tackles': 3,
#                  'team_a_score': 0,
#                  'team_h_score': 0,
#                  'threat': '29.0',
#                  'total_points': 2,
#                  'transfers_balance': 1808,
#                  'transfers_in': 28021,
#                  'transfers_out': 26213,
#                  'value': 151,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 9,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 1,
#                  'creativity': '2.5',
#                  'defensive_contribution': 4,
#                  'element': 430,
#                  'expected_assists': '0.02',
#                  'expected_goal_involvements': '0.43',
#                  'expected_goals': '0.41',
#                  'expected_goals_conceded': '1.73',
#                  'fixture': 197,
#                  'goals_conceded': 1,
#                  'goals_scored': 0,
#                  'ict_index': '2.9',
#                  'influence': '3.4',
#                  'kickoff_time': '2026-01-04T17:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 7,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 3,
#                  'red_cards': 0,
#                  'round': 20,
#                  'saves': 0,
#                  'selected': 9456264,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 1,
#                  'team_h_score': 1,
#                  'threat': '23.0',
#                  'total_points': 2,
#                  'transfers_balance': -6602,
#                  'transfers_in': 21846,
#                  'transfers_out': 28448,
#                  'value': 151,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 18,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 1,
#                  'creativity': '12.0',
#                  'defensive_contribution': 3,
#                  'element': 430,
#                  'expected_assists': '0.02',
#                  'expected_goal_involvements': '1.55',
#                  'expected_goals': '1.53',
#                  'expected_goals_conceded': '1.16',
#                  'fixture': 208,
#                  'goals_conceded': 1,
#                  'goals_scored': 1,
#                  'ict_index': '12.0',
#                  'influence': '42.6',
#                  'kickoff_time': '2026-01-07T19:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 6,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 1,
#                  'red_cards': 0,
#                  'round': 21,
#                  'saves': 0,
#                  'selected': 9487662,
#                  'starts': 1,
#                  'tackles': 1,
#                  'team_a_score': 1,
#                  'team_h_score': 1,
#                  'threat': '65.0',
#                  'total_points': 6,
#                  'transfers_balance': 7913,
#                  'transfers_in': 29456,
#                  'transfers_out': 21543,
#                  'value': 151,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 7,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 0,
#                  'creativity': '1.6',
#                  'defensive_contribution': 1,
#                  'element': 430,
#                  'expected_assists': '0.00',
#                  'expected_goal_involvements': '0.13',
#                  'expected_goals': '0.13',
#                  'expected_goals_conceded': '2.11',
#                  'fixture': 216,
#                  'goals_conceded': 2,
#                  'goals_scored': 0,
#                  'ict_index': '1.3',
#                  'influence': '0.0',
#                  'kickoff_time': '2026-01-17T12:30:00Z',
#                  'minutes': 79,
#                  'modified': False,
#                  'opponent_team': 14,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 1,
#                  'red_cards': 0,
#                  'round': 22,
#                  'saves': 0,
#                  'selected': 9515178,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 0,
#                  'team_h_score': 2,
#                  'threat': '12.0',
#                  'total_points': 2,
#                  'transfers_balance': 8887,
#                  'transfers_in': 42345,
#                  'transfers_out': 33458,
#                  'value': 151,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 3,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 0,
#                  'creativity': '0.0',
#                  'defensive_contribution': 0,
#                  'element': 430,
#                  'expected_assists': '0.00',
#                  'expected_goal_involvements': '0.00',
#                  'expected_goals': '0.00',
#                  'expected_goals_conceded': '0.42',
#                  'fixture': 228,
#                  'goals_conceded': 0,
#                  'goals_scored': 0,
#                  'ict_index': '0.0',
#                  'influence': '0.0',
#                  'kickoff_time': '2026-01-24T15:00:00Z',
#                  'minutes': 17,
#                  'modified': False,
#                  'opponent_team': 20,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 23,
#                  'saves': 0,
#                  'selected': 9490416,
#                  'starts': 0,
#                  'tackles': 0,
#                  'team_a_score': 0,
#                  'team_h_score': 2,
#                  'threat': '0.0',
#                  'total_points': 1,
#                  'transfers_balance': -39745,
#                  'transfers_in': 29197,
#                  'transfers_out': 68942,
#                  'value': 151,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 1,
#                  'bonus': 0,
#                  'bps': 17,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 1,
#                  'creativity': '41.0',
#                  'defensive_contribution': 2,
#                  'element': 430,
#                  'expected_assists': '0.07',
#                  'expected_goal_involvements': '0.35',
#                  'expected_goals': '0.28',
#                  'expected_goals_conceded': '1.05',
#                  'fixture': 239,
#                  'goals_conceded': 2,
#                  'goals_scored': 0,
#                  'ict_index': '8.5',
#                  'influence': '26.8',
#                  'kickoff_time': '2026-02-01T16:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 18,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 24,
#                  'saves': 0,
#                  'selected': 9220081,
#                  'starts': 1,
#                  'tackles': 1,
#                  'team_a_score': 2,
#                  'team_h_score': 2,
#                  'threat': '17.0',
#                  'total_points': 5,
#                  'transfers_balance': -260605,
#                  'transfers_in': 23980,
#                  'transfers_out': 284585,
#                  'value': 150,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 1,
#                  'bonus': 3,
#                  'bps': 35,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 1,
#                  'creativity': '35.3',
#                  'defensive_contribution': 1,
#                  'element': 430,
#                  'expected_assists': '0.31',
#                  'expected_goal_involvements': '1.66',
#                  'expected_goals': '1.35',
#                  'expected_goals_conceded': '1.21',
#                  'fixture': 247,
#                  'goals_conceded': 1,
#                  'goals_scored': 1,
#                  'ict_index': '15.9',
#                  'influence': '60.8',
#                  'kickoff_time': '2026-02-08T16:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 12,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 25,
#                  'saves': 0,
#                  'selected': 8927414,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 2,
#                  'team_h_score': 1,
#                  'threat': '63.0',
#                  'total_points': 11,
#                  'transfers_balance': -279386,
#                  'transfers_in': 14029,
#                  'transfers_out': 293415,
#                  'value': 149,
#                  'was_home': False,
#                  'yellow_cards': 1},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 29,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 0,
#                  'creativity': '0.6',
#                  'defensive_contribution': 1,
#                  'element': 430,
#                  'expected_assists': '0.00',
#                  'expected_goal_involvements': '0.12',
#                  'expected_goals': '0.12',
#                  'expected_goals_conceded': '0.62',
#                  'fixture': 256,
#                  'goals_conceded': 0,
#                  'goals_scored': 1,
#                  'ict_index': '4.4',
#                  'influence': '32.0',
#                  'kickoff_time': '2026-02-11T19:30:00Z',
#                  'minutes': 45,
#                  'modified': False,
#                  'opponent_team': 10,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 1,
#                  'red_cards': 0,
#                  'round': 26,
#                  'saves': 0,
#                  'selected': 8866152,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 0,
#                  'team_h_score': 3,
#                  'threat': '11.0',
#                  'total_points': 5,
#                  'transfers_balance': -96287,
#                  'transfers_in': 42325,
#                  'transfers_out': 138612,
#                  'value': 149,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 1,
#                  'bonus': 1,
#                  'bps': 22,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 3,
#                  'creativity': '18.1',
#                  'defensive_contribution': 4,
#                  'element': 430,
#                  'expected_assists': '0.22',
#                  'expected_goal_involvements': '0.53',
#                  'expected_goals': '0.31',
#                  'expected_goals_conceded': '0.62',
#                  'fixture': 266,
#                  'goals_conceded': 1,
#                  'goals_scored': 0,
#                  'ict_index': '8.1',
#                  'influence': '27.2',
#                  'kickoff_time': '2026-02-21T20:00:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 15,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 27,
#                  'saves': 0,
#                  'selected': 8672580,
#                  'starts': 1,
#                  'tackles': 1,
#                  'team_a_score': 1,
#                  'team_h_score': 2,
#                  'threat': '36.0',
#                  'total_points': 6,
#                  'transfers_balance': -209144,
#                  'transfers_in': 34443,
#                  'transfers_out': 243587,
#                  'value': 148,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 0,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 0,
#                  'creativity': '0.0',
#                  'defensive_contribution': 0,
#                  'element': 430,
#                  'expected_assists': '0.00',
#                  'expected_goal_involvements': '0.00',
#                  'expected_goals': '0.00',
#                  'expected_goals_conceded': '0.00',
#                  'fixture': 276,
#                  'goals_conceded': 0,
#                  'goals_scored': 0,
#                  'ict_index': '0.0',
#                  'influence': '0.0',
#                  'kickoff_time': '2026-02-28T17:30:00Z',
#                  'minutes': 0,
#                  'modified': False,
#                  'opponent_team': 11,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 0,
#                  'red_cards': 0,
#                  'round': 28,
#                  'saves': 0,
#                  'selected': 8750116,
#                  'starts': 0,
#                  'tackles': 0,
#                  'team_a_score': 1,
#                  'team_h_score': 0,
#                  'threat': '0.0',
#                  'total_points': 0,
#                  'transfers_balance': 41859,
#                  'transfers_in': 74152,
#                  'transfers_out': 32293,
#                  'value': 148,
#                  'was_home': False,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 0,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 2,
#                  'creativity': '1.8',
#                  'defensive_contribution': 3,
#                  'element': 430,
#                  'expected_assists': '0.03',
#                  'expected_goal_involvements': '0.13',
#                  'expected_goals': '0.10',
#                  'expected_goals_conceded': '0.97',
#                  'fixture': 287,
#                  'goals_conceded': 2,
#                  'goals_scored': 0,
#                  'ict_index': '2.1',
#                  'influence': '0.0',
#                  'kickoff_time': '2026-03-04T19:30:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 16,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 1,
#                  'red_cards': 0,
#                  'round': 29,
#                  'saves': 0,
#                  'selected': 8018821,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 2,
#                  'team_h_score': 2,
#                  'threat': '19.0',
#                  'total_points': 2,
#                  'transfers_balance': -679051,
#                  'transfers_in': 11705,
#                  'transfers_out': 690756,
#                  'value': 147,
#                  'was_home': True,
#                  'yellow_cards': 0},
#                { 'assists': 0,
#                  'bonus': 0,
#                  'bps': 7,
#                  'clean_sheets': 0,
#                  'clearances_blocks_interceptions': 0,
#                  'creativity': '13.6',
#                  'defensive_contribution': 2,
#                  'element': 430,
#                  'expected_assists': '0.05',
#                  'expected_goal_involvements': '0.35',
#                  'expected_goals': '0.30',
#                  'expected_goals_conceded': '0.54',
#                  'fixture': 300,
#                  'goals_conceded': 1,
#                  'goals_scored': 0,
#                  'ict_index': '5.3',
#                  'influence': '1.6',
#                  'kickoff_time': '2026-03-14T20:00:00Z',
#                  'minutes': 90,
#                  'modified': False,
#                  'opponent_team': 19,
#                  'own_goals': 0,
#                  'penalties_missed': 0,
#                  'penalties_saved': 0,
#                  'recoveries': 2,
#                  'red_cards': 0,
#                  'round': 30,
#                  'saves': 0,
#                  'selected': 7807912,
#                  'starts': 1,
#                  'tackles': 0,
#                  'team_a_score': 1,
#                  'team_h_score': 1,
#                  'threat': '38.0',
#                  'total_points': 2,
#                  'transfers_balance': -263818,
#                  'transfers_in': 56569,
#                  'transfers_out': 320387,
#                  'value': 146,
#                  'was_home': False,
#                  'yellow_cards': 0}],
#   'history_past': [ { 'assists': 9,
#                       'bonus': 40,
#                       'bps': 1040,
#                       'clean_sheets': 13,
#                       'clearances_blocks_interceptions': 0,
#                       'creativity': '371.0',
#                       'defensive_contribution': 0,
#                       'element_code': 223094,
#                       'end_cost': 124,
#                       'expected_assists': '3.11',
#                       'expected_goal_involvements': '31.65',
#                       'expected_goals': '28.54',
#                       'expected_goals_conceded': '25.24',
#                       'goals_conceded': 26,
#                       'goals_scored': 36,
#                       'ict_index': '358.1',
#                       'influence': '1390.0',
#                       'minutes': 2767,
#                       'own_goals': 0,
#                       'penalties_missed': 0,
#                       'penalties_saved': 0,
#                       'recoveries': 0,
#                       'red_cards': 0,
#                       'saves': 0,
#                       'season_name': '2022/23',
#                       'start_cost': 115,
#                       'starts': 33,
#                       'tackles': 0,
#                       'threat': '1825.0',
#                       'total_points': 272,
#                       'yellow_cards': 5},
#                     { 'assists': 8,
#                       'bonus': 29,
#                       'bps': 792,
#                       'clean_sheets': 11,
#                       'clearances_blocks_interceptions': 0,
#                       'creativity': '367.2',
#                       'defensive_contribution': 0,
#                       'element_code': 223094,
#                       'end_cost': 143,
#                       'expected_assists': '2.18',
#                       'expected_goal_involvements': '31.75',
#                       'expected_goals': '29.57',
#                       'expected_goals_conceded': '25.65',
#                       'goals_conceded': 25,
#                       'goals_scored': 27,
#                       'ict_index': '303.3',
#                       'influence': '1094.6',
#                       'minutes': 2553,
#                       'own_goals': 0,
#                       'penalties_missed': 1,
#                       'penalties_saved': 0,
#                       'recoveries': 0,
#                       'red_cards': 0,
#                       'saves': 0,
#                       'season_name': '2023/24',
#                       'start_cost': 140,
#                       'starts': 29,
#                       'tackles': 0,
#                       'threat': '1581.0',
#                       'total_points': 217,
#                       'yellow_cards': 1},
#                     { 'assists': 3,
#                       'bonus': 26,
#                       'bps': 795,
#                       'clean_sheets': 10,
#                       'clearances_blocks_interceptions': 0,
#                       'creativity': '359.4',
#                       'defensive_contribution': 73,
#                       'element_code': 223094,
#                       'end_cost': 149,
#                       'expected_assists': '2.04',
#                       'expected_goal_involvements': '23.94',
#                       'expected_goals': '21.90',
#                       'expected_goals_conceded': '41.27',
#                       'goals_conceded': 38,
#                       'goals_scored': 22,
#                       'ict_index': '281.8',
#                       'influence': '946.0',
#                       'minutes': 2736,
#                       'own_goals': 0,
#                       'penalties_missed': 1,
#                       'penalties_saved': 0,
#                       'recoveries': 0,
#                       'red_cards': 0,
#                       'saves': 0,
#                       'season_name': '2024/25',
#                       'start_cost': 150,
#                       'starts': 31,
#                       'tackles': 0,
#                       'threat': '1511.0',
#                       'total_points': 181,
#                       'yellow_cards': 2}]}

# %%
df_history = pd.json_normalize(data['history'])
df_history.head()
# Out:
#    element  fixture  opponent_team  total_points  was_home  \
# 0      430        7             20            13     False
# 1      430       18             18             2      True
# 2      430       22              6             9     False
# 3      430       38             14            13      True
# 4      430       41              1             9     False
#
#            kickoff_time  team_h_score  team_a_score  round  modified  ...  \
# 0  2025-08-16T16:30:00Z             0             4      1     False  ...
# 1  2025-08-23T11:30:00Z             0             2      2     False  ...
# 2  2025-08-31T13:00:00Z             2             1      3     False  ...
# 3  2025-09-14T15:30:00Z             3             0      4     False  ...
# 4  2025-09-21T15:30:00Z             1             1      5     False  ...
#
#    starts  expected_goals  expected_assists  expected_goal_involvements  \
# 0       1            1.99              0.00                        1.99
# 1       1            0.47              0.30                        0.77
# 2       1            1.40              0.00                        1.40
# 3       1            1.80              0.01                        1.81
# 4       1            0.52              0.01                        0.53
#
#    expected_goals_conceded  value  transfers_balance  selected  transfers_in  \
# 0                     0.35    140                  0   2283987             0
# 1                     1.11    140             396573   3276879        446334
# 2                     2.30    141             179096   3747441        366370
# 3                     1.42    141             209666   3931425        435454
# 4                     0.77    142             405468   4419019        479550
#
#    transfers_out
# 0              0
# 1          49761
# 2         187274
# 3         225788
# 4          74082
#
# [5 rows x 41 columns]

# %%
data = get_json_data('event/5/live')
pprint(data, indent=2)
# Out:
# <Response [200]>
# { 'elements': [ { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 2,
#                                               'points_modification': 0,
#                                               'value': 90}]}],
#                   'id': 1,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 13,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 1,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.01',
#                              'expected_goal_involvements': '0.01',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.89',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '2.1',
#                              'in_dreamteam': False,
#                              'influence': '21.4',
#                              'minutes': 90,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 6,
#                              'red_cards': 0,
#                              'saves': 2,
#                              'starts': 1,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 2,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 2,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 3,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 4,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 2,
#                                               'points_modification': 0,
#                                               'value': 90}]}],
#                   'id': 5,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 13,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 7,
#                              'creativity': '2.3',
#                              'defensive_contribution': 8,
#                              'expected_assists': '0.01',
#                              'expected_goal_involvements': '0.01',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.89',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '2.2',
#                              'in_dreamteam': False,
#                              'influence': '19.6',
#                              'minutes': 90,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 1,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 1,
#                              'threat': '0.0',
#                              'total_points': 2,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 2,
#                                               'points_modification': 0,
#                                               'value': 90}]}],
#                   'id': 6,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 15,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 5,
#                              'creativity': '3.0',
#                              'defensive_contribution': 9,
#                              'expected_assists': '0.02',
#                              'expected_goal_involvements': '0.15',
#                              'expected_goals': '0.13',
#                              'expected_goals_conceded': '0.89',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '2.9',
#                              'in_dreamteam': False,
#                              'influence': '22.0',
#                              'minutes': 90,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 8,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 4,
#                              'threat': '4.0',
#                              'total_points': 2,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 2,
#                                               'points_modification': 0,
#                                               'value': 90}]}],
#                   'id': 7,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 7,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 2,
#                              'creativity': '6.2',
#                              'defensive_contribution': 5,
#                              'expected_assists': '0.05',
#                              'expected_goal_involvements': '0.19',
#                              'expected_goals': '0.14',
#                              'expected_goals_conceded': '0.89',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '2.9',
#                              'in_dreamteam': False,
#                              'influence': '3.6',
#                              'minutes': 90,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 6,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 3,
#                              'threat': '19.0',
#                              'total_points': 2,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 2,
#                                               'points_modification': 0,
#                                               'value': 79},
#                                             { 'identifier': 'yellow_cards',
#                                               'points': -1,
#                                               'points_modification': 0,
#                                               'value': 1}]}],
#                   'id': 8,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 16,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 1,
#                              'creativity': '13.9',
#                              'defensive_contribution': 8,
#                              'expected_assists': '0.05',
#                              'expected_goal_involvements': '0.05',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.65',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '3.9',
#                              'in_dreamteam': False,
#                              'influence': '17.0',
#                              'minutes': 79,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 3,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 7,
#                              'threat': '8.0',
#                              'total_points': 1,
#                              'yellow_cards': 1}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 9,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 10,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 11,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 44,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 2,
#                                               'points_modification': 0,
#                                               'value': 90}]}],
#                   'id': 12,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 19,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 6,
#                              'creativity': '18.0',
#                              'defensive_contribution': 9,
#                              'expected_assists': '0.07',
#                              'expected_goal_involvements': '0.11',
#                              'expected_goals': '0.04',
#                              'expected_goals_conceded': '0.85',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '6.3',
#                              'in_dreamteam': False,
#                              'influence': '29.6',
#                              'minutes': 90,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 6,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 3,
#                              'threat': '15.0',
#                              'total_points': 2,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 13,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 14,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 15,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 1,
#                                               'points_modification': 0,
#                                               'value': 45}]}],
#                   'id': 16,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 7,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '32.3',
#                              'defensive_contribution': 3,
#                              'expected_assists': '0.21',
#                              'expected_goal_involvements': '0.25',
#                              'expected_goals': '0.04',
#                              'expected_goals_conceded': '0.34',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '4.5',
#                              'in_dreamteam': False,
#                              'influence': '5.6',
#                              'minutes': 45,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 3,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '7.0',
#                              'total_points': 1,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 17,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 1,
#                                               'points_modification': 0,
#                                               'value': 45}]}],
#                   'id': 18,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': -2,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '1.7',
#                              'defensive_contribution': 2,
#                              'expected_assists': '0.01',
#                              'expected_goal_involvements': '0.16',
#                              'expected_goals': '0.15',
#                              'expected_goals_conceded': '0.55',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '3.1',
#                              'in_dreamteam': False,
#                              'influence': '0.4',
#                              'minutes': 45,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 2,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 0,
#                              'threat': '29.0',
#                              'total_points': 1,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 1,
#                                               'points_modification': 0,
#                                               'value': 10},
#                                             { 'identifier': 'goals_scored',
#                                               'points': 5,
#                                               'points_modification': 0,
#                                               'value': 1},
#                                             { 'identifier': 'bonus',
#                                               'points': 1,
#                                               'points_modification': 0,
#                                               'value': 1}]}],
#                   'id': 19,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 1,
#                              'bps': 22,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.3',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.16',
#                              'expected_goals': '0.16',
#                              'expected_goals_conceded': '0.25',
#                              'goals_conceded': 0,
#                              'goals_scored': 1,
#                              'ict_index': '5.0',
#                              'in_dreamteam': False,
#                              'influence': '33.0',
#                              'minutes': 10,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '17.0',
#                              'total_points': 7,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 2,
#                                               'points_modification': 0,
#                                               'value': 83}]}],
#                   'id': 20,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 13,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 2,
#                              'creativity': '4.3',
#                              'defensive_contribution': 4,
#                              'expected_assists': '0.07',
#                              'expected_goal_involvements': '0.21',
#                              'expected_goals': '0.14',
#                              'expected_goals_conceded': '0.89',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '2.9',
#                              'in_dreamteam': False,
#                              'influence': '7.6',
#                              'minutes': 83,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 1,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 1,
#                              'threat': '17.0',
#                              'total_points': 2,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 2,
#                                               'points_modification': 0,
#                                               'value': 90},
#                                             { 'identifier': 'bonus',
#                                               'points': 1,
#                                               'points_modification': 0,
#                                               'value': 1}]}],
#                   'id': 21,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 1,
#                              'bps': 22,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 1,
#                              'creativity': '37.0',
#                              'defensive_contribution': 9,
#                              'expected_assists': '0.16',
#                              'expected_goal_involvements': '0.16',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.89',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '5.6',
#                              'in_dreamteam': False,
#                              'influence': '18.8',
#                              'minutes': 90,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 6,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 2,
#                              'threat': '0.0',
#                              'total_points': 3,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 1,
#                                               'points_modification': 0,
#                                               'value': 45}]}],
#                   'id': 22,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 6,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 2,
#                              'creativity': '17.3',
#                              'defensive_contribution': 7,
#                              'expected_assists': '0.03',
#                              'expected_goal_involvements': '0.03',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.55',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '2.6',
#                              'in_dreamteam': False,
#                              'influence': '8.8',
#                              'minutes': 45,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 4,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 1,
#                              'threat': '0.0',
#                              'total_points': 1,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 23,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 24,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 1,
#                                               'points_modification': 0,
#                                               'value': 6}]}],
#                   'id': 25,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 3,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.4',
#                              'defensive_contribution': 1,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.1',
#                              'in_dreamteam': False,
#                              'influence': '0.2',
#                              'minutes': 6,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 1,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 1,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 2,
#                                               'points_modification': 0,
#                                               'value': 90}]}],
#                   'id': 26,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 13,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 2,
#                              'creativity': '19.0',
#                              'defensive_contribution': 5,
#                              'expected_assists': '0.04',
#                              'expected_goal_involvements': '0.09',
#                              'expected_goals': '0.05',
#                              'expected_goals_conceded': '0.89',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '4.0',
#                              'in_dreamteam': False,
#                              'influence': '8.6',
#                              'minutes': 90,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 3,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 0,
#                              'threat': '12.0',
#                              'total_points': 2,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 45,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 27,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
# ...
#                                               'value': 0}]}],
#                   'id': 733,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 44,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 1,
#                                               'points_modification': 0,
#                                               'value': 58}]}],
#                   'id': 734,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 7,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 1,
#                              'creativity': '14.3',
#                              'defensive_contribution': 6,
#                              'expected_assists': '0.01',
#                              'expected_goal_involvements': '0.07',
#                              'expected_goals': '0.06',
#                              'expected_goals_conceded': '0.51',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '5.3',
#                              'in_dreamteam': False,
#                              'influence': '13.0',
#                              'minutes': 58,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 5,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 1,
#                              'tackles': 0,
#                              'threat': '26.0',
#                              'total_points': 1,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 48,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 735,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 2,
#                                               'points_modification': 0,
#                                               'value': 90},
#                                             { 'identifier': 'yellow_cards',
#                                               'points': -1,
#                                               'points_modification': 0,
#                                               'value': 1}]}],
#                   'id': 736,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 7,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 4,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.96',
#                              'goals_conceded': 1,
#                              'goals_scored': 0,
#                              'ict_index': '1.6',
#                              'in_dreamteam': False,
#                              'influence': '15.6',
#                              'minutes': 90,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 4,
#                              'red_cards': 0,
#                              'saves': 2,
#                              'starts': 1,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 1,
#                              'yellow_cards': 1}},
#                 { 'explain': [ { 'fixture': 45,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 737,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 49,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 738,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 739,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 41,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 740,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}},
#                 { 'explain': [ { 'fixture': 50,
#                                  'stats': [ { 'identifier': 'minutes',
#                                               'points': 0,
#                                               'points_modification': 0,
#                                               'value': 0}]}],
#                   'id': 741,
#                   'modified': False,
#                   'stats': { 'assists': 0,
#                              'bonus': 0,
#                              'bps': 0,
#                              'clean_sheets': 0,
#                              'clearances_blocks_interceptions': 0,
#                              'creativity': '0.0',
#                              'defensive_contribution': 0,
#                              'expected_assists': '0.00',
#                              'expected_goal_involvements': '0.00',
#                              'expected_goals': '0.00',
#                              'expected_goals_conceded': '0.00',
#                              'goals_conceded': 0,
#                              'goals_scored': 0,
#                              'ict_index': '0.0',
#                              'in_dreamteam': False,
#                              'influence': '0.0',
#                              'minutes': 0,
#                              'own_goals': 0,
#                              'penalties_missed': 0,
#                              'penalties_saved': 0,
#                              'recoveries': 0,
#                              'red_cards': 0,
#                              'saves': 0,
#                              'starts': 0,
#                              'tackles': 0,
#                              'threat': '0.0',
#                              'total_points': 0,
#                              'yellow_cards': 0}}]}
